# %% [markdown]
# # Exploration of DrugMechDB
#
# Here, I explore [DrugMechDB](https://sulab.github.io/DrugMechDB/) which could ideally provide us with true positive paths / MOAs.

# %%
import pandas as pd
import os.path as osp
from collections import Counter
from urllib import request
import json
from matplotlib import pyplot as plt
from matplotlib_venn import venn2_unweighted
import numpy as np
import math
import requests
from tqdm import tqdm
from pubchempy import get_compounds
from collections import defaultdict

# %% [markdown]
# ## Load in the DrugMechDB file:

# %%
VALIDATION_DIR = '../data/validation'
MAPPING_DIR = '../data/mappings'
KG_DIR = '../data/kg'

# %% [markdown]
# The database download comes as an excel file with many separate sheets, so it needs to be read in as separate dataframes:

# %%
indications = pd.read_excel('../data/mappings/indication_MOA_paths.xlsx', sheet_name='sample_indications')

# %%
indications.head()
# Out:
#             name  num_ind_dc    db_id    comp_mesh_ids  \
# 0       imatinib        11.0  DB00619  MESH:D000068877
# 1       imatinib        11.0  DB00619  MESH:D000068877
# 2       imatinib        11.0  DB00619  MESH:D000068877
# 3  acetaminophen         NaN  DB00316     MESH:D000082
# 4  acetaminophen         NaN  DB00316     MESH:D000082
#
#                  disease_name   dis_mesh_id  \
# 0                   CML (ph+)  MESH:D015464
# 1  Systemic mast cell disease  MESH:D034721
# 2  Systemic mast cell disease  MESH:D034721
# 3                        Pain  MESH:D010146
# 4                        Pain  MESH:D010146
#
#                                             Comments
# 0  Multiple ways to represent this path, experime...
# 1                                                NaN
# 2                                                NaN
# 3  Multiple ways to represent this path, experime...
# 4                                                NaN

# %% [markdown]
# We can see the the drugs are provided as [DrugBank](https://go.drugbank.com) identifiers, and the diseases are providued as [MeSh identifiers](https://www.nlm.nih.gov/mesh/meshhome.html).
#
# Let's look at the paths:
#
# ## Path Instances in DrugMechDB

# %%
paths = pd.read_excel('../data/mappings/indication_MOA_paths.xlsx', sheet_name='paths')

# %%
paths.head()
# Out:
#               n1        e1                      n2               e2  \
# 0       imatinib  INHIBITS                 BCR/ABL           CAUSES
# 1       imatinib  INHIBITS                   c-Kit     UP_REGULATES
# 2       imatinib  INHIBITS                    Pdgf     UP_REGULATES
# 3  acetaminophen  INHIBITS  cycloxygenaze pathways  ASSOCIATED_WITH
# 4  acetaminophen  INHIBITS                   Cox-1         PRODUCES
#
#                        n3      e3                          n4   e4   n5   e5  \
# 0               CML (ph+)     NaN                         NaN  NaN  NaN  NaN
# 1  Cellular proliferation  CAUSES  Systemic mast cell disease  NaN  NaN  NaN
# 2  Cellular proliferation  CAUSES  Systemic mast cell disease  NaN  NaN  NaN
# 3                    Pain     NaN                         NaN  NaN  NaN  NaN
# 4          Prostaglandins  CAUSES                        Pain  NaN  NaN  NaN
#
#     n6   e6   n7   e7   n8
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# How long are most of the paths? I'll define the length of the paths as the number of edges/hops.

# %%
Counter([(row.count() - 1) / 2 for i, row in paths.iterrows()])
# Out:
# Counter({4.0: 59, 3.0: 38, 2.0: 13, 5.0: 8, 1.0: 3, 7.0: 1, 6.0: 1})

# %% [markdown]
# It looks like most are length 4.
#
# Only 3 are above length 5.
#
# What if we only take those which end in a biological process?
#
# It might be better to work from the JSON file instead, which can be found [here](https://github.com/SuLab/DrugMechDB/blob/1.0/indication_paths.json). In contrast to the paths in the dataframe, the JSON version has the types for each node.

# %%
url = "https://raw.githubusercontent.com/SuLab/DrugMechDB/1.0/indication_paths.json"
filepath = "../data/mappings/drugmechdb_paths.json"

# %%
with request.urlopen(url) as fl:
    data_json = json.loads(fl.read())

# %% [markdown]
# Are there the same number of paths as before?

# %%
len(data_json)
# Out:
# 123

# %%
data_json
# Out:
# [{'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'imatinib',
#    'disease': 'CML (ph+)',
#    'drugbank': 'DB00619',
#    'drug_mesh': 'MESH:D000068877',
#    'disease_mesh': 'MESH:D015464'},
#   'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#    {'id': 'UniProt:P00519', 'name': 'BCR/ABL', 'label': 'Protein'},
#    {'id': 'MESH:D015464', 'name': 'CML (ph+)', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068877',
#     'target': 'UniProt:P00519',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P00519', 'target': 'MESH:D015464', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'imatinib',
#    'disease': 'Systemic mast cell disease',
#    'drugbank': 'DB00619',
#    'drug_mesh': 'MESH:D000068877',
#    'disease_mesh': 'MESH:D034721'},
#   'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#    {'id': 'UniProt:P10721', 'name': 'c-Kit', 'label': 'Protein'},
#    {'id': 'GO:0008283',
#     'name': 'Cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D034721',
#     'name': 'Systemic mast cell disease',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068877',
#     'target': 'UniProt:P10721',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P10721', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'imatinib',
#    'disease': 'Systemic mast cell disease',
#    'drugbank': 'DB00619',
#    'drug_mesh': 'MESH:D000068877',
#    'disease_mesh': 'MESH:D034721'},
#   'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#    {'id': 'UniProt:P16234', 'name': 'Pdgf', 'label': 'Protein'},
#    {'id': 'GO:0008283',
#     'name': 'Cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D034721',
#     'name': 'Systemic mast cell disease',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068877',
#     'target': 'UniProt:P16234',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P16234', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetaminophen',
#    'disease': 'Pain',
#    'drugbank': 'DB00316',
#    'drug_mesh': 'MESH:D000082',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen', 'label': 'Drug'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'cycloxygenaze pathways',
#     'label': 'Pathway'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000082',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'INHIBITS'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'MESH:D010146',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetaminophen',
#    'disease': 'Pain',
#    'drugbank': 'DB00316',
#    'drug_mesh': 'MESH:D000082',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen', 'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'Cox-1', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000082',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetaminophen',
#    'disease': 'Pain',
#    'drugbank': 'DB00316',
#    'drug_mesh': 'MESH:D000082',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen', 'label': 'Drug'},
#    {'id': 'UniProt:P35354', 'name': 'Cox-2', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000082',
#     'target': 'UniProt:P35354',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35354', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetaminophen',
#    'disease': 'Fever',
#    'drugbank': 'DB00316',
#    'drug_mesh': 'MESH:D000082',
#    'disease_mesh': 'MESH:D005334'},
#   'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen', 'label': 'Drug'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'cycloxygenaze pathways',
#     'label': 'Pathway'},
#    {'id': 'UBERON:0000955', 'name': 'Brain', 'label': 'Anatomy'},
#    {'id': 'GO:0001659',
#     'name': 'Temperature Homeostasis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D005334', 'name': 'Fever', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000082',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'INHIBITS'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'UBERON:0000955',
#     'key': 'LOCALIZED_TO'},
#    {'source': 'UBERON:0000955', 'target': 'GO:0001659', 'key': 'REGULATES'},
#    {'source': 'GO:0001659', 'target': 'MESH:D005334', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Pain',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'Cox-1', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Pain',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P35354', 'name': 'Cox-2', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P35354',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35354', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Thrombosis',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D013927'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Synthesis of Prostaglandins and Thromboxanes',
#     'label': 'Pathway'},
#    {'id': 'MESH:D013928', 'name': 'Thromboxane A2', 'label': 'Compound'},
#    {'id': 'GO:0007596',
#     'name': 'Platelet Activiation / Blood Coagulation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013927', 'name': 'Thrombosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'PART_OF'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'MESH:D013928',
#     'key': 'PRODUCES'},
#    {'source': 'MESH:D013928', 'target': 'GO:0007596', 'key': 'PART_OF'},
#    {'source': 'GO:0007596', 'target': 'MESH:D013927', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Thrombosis',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D013927'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX', 'label': 'Protein'},
#    {'id': 'GO:0007596',
#     'name': 'Blood Coagulation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013927', 'name': 'Thrombosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219', 'target': 'GO:0007596', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0007596', 'target': 'MESH:D013927', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'naproxen',
#    'disease': 'Pain',
#    'drugbank': 'DB00788',
#    'drug_mesh': 'MESH:D009288',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D009288', 'name': 'naproxen', 'label': 'Drug'},
#    {'id': 'UniProt:P35354', 'name': 'Cox-2', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009288',
#     'target': 'UniProt:P35354',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35354', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norfloxacin',
#    'disease': 'Shigellosis',
#    'drugbank': 'DB01059',
#    'drug_mesh': 'MESH:D009643',
#    'disease_mesh': 'MESH:D004405'},
#   'nodes': [{'id': 'MESH:D009643', 'name': 'norfloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P43702',
#     'name': 'topoisomerases II, IV',
#     'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bactierial DNA Replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:622', 'name': 'Shigella dysenteriae', 'label': 'Taxon'},
#    {'id': 'MESH:D004405', 'name': 'Shigellosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009643',
#     'target': 'UniProt:P43702',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P43702', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:622', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:622', 'target': 'MESH:D004405', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norfloxacin',
#    'disease': 'Shigellosis',
#    'drugbank': 'DB01059',
#    'drug_mesh': 'MESH:D009643',
#    'disease_mesh': 'MESH:D004405'},
#   'nodes': [{'id': 'MESH:D009643', 'name': 'norfloxacin', 'label': 'Drug'},
#    {'id': 'GO:0003746',
#     'name': 'Translocation of EF-G',
#     'label': 'Molecular Function'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Protein Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:622', 'name': 'Shigella dysenteriae', 'label': 'Taxon'},
#    {'id': 'MESH:D004405', 'name': 'Shigellosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009643',
#     'target': 'GO:0003746',
#     'key': 'INHIBITS'},
#    {'source': 'GO:0003746', 'target': 'GO:0006412', 'key': 'REQUIRED_FOR'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:622', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:622', 'target': 'MESH:D004405', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04083', 'name': 'lipocortin-1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04083',
#     'key': 'INCREASES_EXPRESSION'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX Genes', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P23219',
#     'key': 'DECREASES_EXPRESSION'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04083', 'name': 'lipocortin-1', 'label': 'Protein'},
#    {'id': 'GO:0050900', 'name': 'Immune Cell Funciton', 'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04083',
#     'key': 'INCREASES_EXPRESSION'},
#    {'source': 'UniProt:P04083',
#     'target': 'GO:0050900',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0050900', 'target': 'GO:0006954', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P04083', 'name': 'Annexin A1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P23219', 'name': 'COX genes', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P23219',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'valganciclovir',
#    'disease': 'CMV infection',
#    'drugbank': 'DB01610',
#    'drug_mesh': 'MESH:D000077562',
#    'disease_mesh': 'MESH:D003586'},
#   'nodes': [{'id': 'MESH:D000077562',
#     'name': 'valganciclovir',
#     'label': 'Drug'},
#    {'id': 'MESH:D015774', 'name': 'ganciclovir', 'label': 'Compound'},
#    {'id': 'GO:0039693',
#     'name': 'viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:10358', 'name': 'Cytomegalovirus', 'label': 'Taxon'},
#    {'id': 'MESH:D003586', 'name': 'CMV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000077562',
#     'target': 'MESH:D015774',
#     'key': 'INCREASES'},
#    {'source': 'MESH:D015774', 'target': 'GO:0039693', 'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0039693',
#     'target': 'NCBITaxon:10358',
#     'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:10358', 'target': 'MESH:D003586', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'metronidazole',
#    'disease': 'Bacterial septicemia',
#    'drugbank': 'DB00916',
#    'drug_mesh': 'MESH:D008795',
#    'disease_mesh': 'MESH:D018805'},
#   'nodes': [{'id': 'MESH:D008795', 'name': 'metronidazole', 'label': 'Drug'},
#    {'id': 'MESH:C029371',
#     'name': 'hydroxyethyl oxamic acid',
#     'label': 'Compound'},
#    {'id': 'GO:0003676',
#     'name': 'bacterial Nucleic Acid synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:2', 'name': 'Bacteria', 'label': 'Taxon'},
#    {'id': 'MESH:D018805', 'name': 'Bacterial septicemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D008795',
#     'target': 'MESH:C029371',
#     'key': 'INCREASES'},
#    {'source': 'MESH:C029371', 'target': 'GO:0003676', 'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0003676', 'target': 'NCBITaxon:2', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:2', 'target': 'MESH:D018805', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'demeclocycline',
#    'disease': 'Rickettsialpox',
#    'drugbank': 'DB00618',
#    'drug_mesh': 'MESH:D003707',
#    'disease_mesh': 'MESH:D000073605'},
#   'nodes': [{'id': 'MESH:D003707', 'name': 'demeclocycline', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7S3',
#     'name': '30S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:786', 'name': 'Rickettsia akari', 'label': 'Taxon'},
#    {'id': 'MESH:D000073605', 'name': 'Rickettsialpox', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7S3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7S3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:786', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:786', 'target': 'MESH:D000073605', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'demeclocycline',
#    'disease': 'Rickettsialpox',
#    'drugbank': 'DB00618',
#    'drug_mesh': 'MESH:D003707',
#    'disease_mesh': 'MESH:D000073605'},
#   'nodes': [{'id': 'MESH:D003707', 'name': 'demeclocycline', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7J3',
#     'name': '50S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:786', 'name': 'Rickettsia akari', 'label': 'Taxon'},
#    {'id': 'MESH:D000073605', 'name': 'Rickettsialpox', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7J3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7J3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:786', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:786', 'target': 'MESH:D000073605', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'amoxicillin',
#    'disease': 'Streptococcal tonsillitis',
#    'drugbank': 'DB01060',
#    'drug_mesh': 'MESH:D000658',
#    'disease_mesh': 'MESH:D014069'},
#   'nodes': [{'id': 'MESH:D000658', 'name': 'amoxicillin', 'label': 'Drug'},
#    {'id': 'UniProt:P71707',
#     'name': 'Penicillin-binding protein 1A',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Peptidoglycan Biosyntheic Process',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1314',
#     'name': 'Streptococcus pyogenes',
#     'label': 'Taxon'},
#    {'id': 'MESH:D014069',
#     'name': 'Streptococcal tonsillitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000658',
#     'target': 'UniProt:P71707',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P71707', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:1314', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1314', 'target': 'MESH:D014069', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'alatrofloxacin',
#    'disease': 'Staphylococcal pneumonia',
#    'drugbank': 'DB09335',
#    'drug_mesh': 'MESH:C106856',
#    'disease_mesh': 'MESH:D011023'},
#   'nodes': [{'id': 'MESH:C106856', 'name': 'alatrofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P0C1U9', 'name': 'Topoisomeraze 4', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1280', 'name': 'Staphylococcus aureus', 'label': 'Taxon'},
#    {'id': 'MESH:D011023',
#     'name': 'Staphylococcal pneumonia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106856',
#     'target': 'UniProt:P0C1U9',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0C1U9', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:1280', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1280', 'target': 'MESH:D011023', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'alatrofloxacin',
#    'disease': 'Staphylococcal pneumonia',
#    'drugbank': 'DB09335',
#    'drug_mesh': 'MESH:C106856',
#    'disease_mesh': 'MESH:D011023'},
#   'nodes': [{'id': 'MESH:C106856', 'name': 'alatrofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P20831', 'name': 'DNA gyrase', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1280', 'name': 'Staphylococcus aureus', 'label': 'Taxon'},
#    {'id': 'MESH:D011023',
#     'name': 'Staphylococcal pneumonia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106856',
#     'target': 'UniProt:P20831',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P20831', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:1280', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1280', 'target': 'MESH:D011023', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'amikacin',
#    'disease': 'Bacterial meningitis',
#    'drugbank': 'DB00479',
#    'drug_mesh': 'MESH:D000583',
#    'disease_mesh': 'MESH:D016920'},
#   'nodes': [{'id': 'MESH:D000583', 'name': 'amikacin', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7S3',
#     'name': '30S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:2', 'name': 'Bacteria', 'label': 'Taxon'},
#    {'id': 'MESH:D016920', 'name': 'Bacterial meningitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000583',
#     'target': 'UniProt:P0A7S3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7S3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:2', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:2', 'target': 'MESH:D016920', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'dexamethasone',
#    'disease': 'Tenosynovitis',
#    'drugbank': 'DB01234',
#    'drug_mesh': 'MESH:D003907',
#    'disease_mesh': 'MESH:D013717'},
#   'nodes': [{'id': 'MESH:D003907', 'name': 'dexamethasone', 'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P04083', 'name': 'Annexin A1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D013717', 'name': 'Tenosynovitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003907',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D013717', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftazidime',
#    'disease': 'Bacterial urinary infection',
#    'drugbank': 'DB00438',
#    'drug_mesh': 'MESH:D002442',
#    'disease_mesh': 'MESH:D014552'},
#   'nodes': [{'id': 'MESH:D002442', 'name': 'ceftazidime', 'label': 'Drug'},
#    {'id': 'UniProt:Q8DR59',
#     'name': 'Penicillin-binding proteins',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:562', 'name': 'Escherichia coli', 'label': 'Taxon'},
#    {'id': 'MESH:D014552',
#     'name': 'Bacterial urinary infection',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D002442',
#     'target': 'UniProt:Q8DR59',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q8DR59', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:562', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:562', 'target': 'MESH:D014552', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'pinacidil',
#    'disease': 'Hypertension',
#    'drugbank': 'DB06762',
#    'drug_mesh': 'MESH:D020110',
#    'disease_mesh': 'MESH:D006973'},
#   'nodes': [{'id': 'MESH:D020110', 'name': 'pinacidil', 'label': 'Drug'},
#    {'id': 'UniProt:Q12791',
#     'name': 'Calcium-activated potassium channel subunit alpha-1',
#     'label': 'Protein'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Negative Regulation of Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D006973', 'name': 'Hypertension', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D020110',
#     'target': 'UniProt:Q12791',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q12791', 'target': 'GO:0042311', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042311', 'target': 'GO:0008217', 'key': 'ASSOCIATED_WITH'},
#    {'source': 'GO:0008217', 'target': 'MESH:D006973', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'posaconazole',
#    'disease': 'Fungal Infection',
#    'drugbank': 'DB01263',
#    'drug_mesh': 'MESH:C101425',
#    'disease_mesh': 'MESH:D009181'},
#   'nodes': [{'id': 'MESH:C101425', 'name': 'posaconazole', 'label': 'Drug'},
#    {'id': 'UniProt:P10613',
#     'name': 'sterol 14a-demethylase',
#     'label': 'Protein'},
#    {'id': 'MESH:D004875', 'name': 'ergosterol', 'label': 'Compound'},
#    {'id': 'GO:0009277',
#     'name': 'Fungal Cell Membrane',
#     'label': 'Cellular Component'},
#    {'id': 'MESH:D009181', 'name': 'Fungal Infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C101425',
#     'target': 'UniProt:P10613',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P10613', 'target': 'MESH:D004875', 'key': 'PRODUCES'},
#    {'source': 'MESH:D004875', 'target': 'GO:0009277', 'key': 'PART_OF'},
#    {'source': 'GO:0009277',
#     'target': 'MESH:D009181',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'antazoline',
#    'disease': 'Vasomotor rhinitis',
#    'drugbank': 'DB08799',
#    'drug_mesh': 'MESH:D000865',
#    'disease_mesh': 'MESH:D012223'},
#   'nodes': [{'id': 'MESH:D000865', 'name': 'antazoline', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D012223', 'name': 'Vasomotor rhinitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000865',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0034776', 'target': 'MESH:D012223', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'levofloxacin',
#    'disease': 'Pyelonephritis',
#    'drugbank': 'DB01137',
#    'drug_mesh': 'MESH:D064704',
#    'disease_mesh': 'MESH:D011704'},
#   'nodes': [{'id': 'MESH:D064704', 'name': 'levofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P11388', 'name': 'DNA gyrase', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:562', 'name': 'E. coli', 'label': 'Taxon'},
#    {'id': 'MESH:D011704', 'name': 'Pyelonephritis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D064704',
#     'target': 'UniProt:P11388',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P11388', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:562', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:562', 'target': 'MESH:D011704', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'meloxicam',
#    'disease': 'Pain',
#    'drugbank': 'DB00814',
#    'drug_mesh': 'MESH:D000077239',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D000077239', 'name': 'meloxicam', 'label': 'Drug'},
#    {'id': 'UniProt:P35354',
#     'name': 'Prostaglandin synthhase 2',
#     'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'InterPro:IPR000265',
#     'name': 'Pain Receptors',
#     'label': 'Protein Family'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000077239',
#     'target': 'UniProt:P35354',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35354', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453',
#     'target': 'InterPro:IPR000265',
#     'key': 'ACTIVATES'},
#    {'source': 'InterPro:IPR000265',
#     'target': 'MESH:D010146',
#     'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'nimodipine',
#    'disease': 'Subarachnoid intracranial hemorrhage',
#    'drugbank': 'DB00393',
#    'drug_mesh': 'MESH:D009553',
#    'disease_mesh': 'MESH:D020300'},
#   'nodes': [{'id': 'MESH:D009553', 'name': 'nimodipine', 'label': 'Drug'},
#    {'id': 'InterPro:IPR005446',
#     'name': 'voltage dependent l-type calcium channels',
#     'label': 'Protein Family'},
#    {'id': 'GO:0006939',
#     'name': 'Smooth muscle contraction',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013345',
#     'name': 'Subarachnoid intracranial hemorrhage',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009553',
#     'target': 'InterPro:IPR005446',
#     'key': 'INHIBITS'},
#    {'source': 'InterPro:IPR005446',
#     'target': 'GO:0006939',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006939', 'target': 'GO:0008217', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008217', 'target': 'MESH:D013345', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'calcium glucoheptonate',
#    'disease': 'hypocalcemia',
#    'drugbank': 'DB00326',
#    'drug_mesh': 'MESH:C007852',
#    'disease_mesh': 'MESH:D006996'},
#   'nodes': [{'id': 'MESH:C007852',
#     'name': 'calcium glucoheptonate',
#     'label': 'Drug'},
#    {'id': 'MESH:D002118', 'name': 'Calcium Ion', 'label': 'Compound'},
#    {'id': 'MESH:D006996', 'name': 'hypocalcemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C007852',
#     'target': 'MESH:D002118',
#     'key': 'INCREASES'},
#    {'source': 'MESH:D002118', 'target': 'MESH:D006996', 'key': 'REDUCED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluticasone propionate',
#    'disease': 'Bronchitis',
#    'drugbank': 'DB00588',
#    'drug_mesh': 'MESH:D000068298',
#    'disease_mesh': 'MESH:D001991'},
#   'nodes': [{'id': 'MESH:D000068298',
#     'name': 'fluticasone propionate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P47712', 'name': 'Phospholipase A2', 'label': 'Protein'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D001991', 'name': 'Bronchitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068298',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P47712',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P47712', 'target': 'GO:0006954', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D001991', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluticasone propionate',
#    'disease': 'Bronchitis',
#    'drugbank': 'DB00588',
#    'drug_mesh': 'MESH:D000068298',
#    'disease_mesh': 'MESH:D001991'},
#   'nodes': [{'id': 'MESH:D000068298',
#     'name': 'fluticasone propionate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P22301', 'name': 'IL-10', 'label': 'Protein'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D001991', 'name': 'Bronchitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068298',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P22301',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P22301',
#     'target': 'GO:0006954',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D001991', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluphenazine',
#    'disease': 'Schizophrenia',
#    'drugbank': 'DB00623',
#    'drug_mesh': 'MESH:D005476',
#    'disease_mesh': 'MESH:D012559'},
#   'nodes': [{'id': 'MESH:D005476', 'name': 'fluphenazine', 'label': 'Drug'},
#    {'id': 'UniProt:P14416',
#     'name': 'D(2) dopamine receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030252',
#     'name': 'growth hormone secretion',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D012559', 'name': 'Schizophrenia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005476',
#     'target': 'UniProt:P14416',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P14416', 'target': 'GO:0030252', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030252', 'target': 'MESH:D012559', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluphenazine',
#    'disease': 'Schizophrenia',
#    'drugbank': 'DB00623',
#    'drug_mesh': 'MESH:D005476',
#    'disease_mesh': 'MESH:D012559'},
#   'nodes': [{'id': 'MESH:D005476', 'name': 'fluphenazine', 'label': 'Drug'},
#    {'id': 'UniProt:P21728',
#     'name': 'dopaminaergeinc receptors',
#     'label': 'Protein'},
#    {'id': 'MESH:D010907',
#     'name': 'hypophyseal hormones',
#     'label': 'Compound Class'},
#    {'id': 'MESH:D012559', 'name': 'Schizophrenia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005476',
#     'target': 'UniProt:P21728',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P21728',
#     'target': 'MESH:D010907',
#     'key': 'UP_REGULATES'},
#    {'source': 'MESH:D010907',
#     'target': 'MESH:D012559',
#     'key': 'UPREGULATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'terfenadine',
#    'disease': 'allergic skin disorders',
#    'drugbank': 'DB00342',
#    'drug_mesh': 'MESH:D016593',
#    'disease_mesh': 'MESH:D065631'},
#   'nodes': [{'id': 'MESH:D016593', 'name': 'terfenadine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'HP:0000969', 'name': 'Edema', 'label': 'Phenotype'},
#    {'id': 'MESH:D017449',
#     'name': 'allergic skin disorders',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D016593',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367',
#     'target': 'HP:0000969',
#     'key': 'ASSOCIATED_WITH'},
#    {'source': 'HP:0000969', 'target': 'MESH:D017449', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'abacavir',
#    'disease': 'HIV infection',
#    'drugbank': 'DB01048',
#    'drug_mesh': 'MESH:C106538',
#    'disease_mesh': 'MESH:D015658'},
#   'nodes': [{'id': 'MESH:C106538', 'name': 'abacavir', 'label': 'Drug'},
#    {'id': 'MESH:C066928',
#     'name': 'carbovir triphosphate',
#     'label': 'Compound'},
#    {'id': 'UniProt:P04585',
#     'name': 'HIV-1 reverse transcriptase',
#     'label': 'Protein'},
#    {'id': 'GO:0039693',
#     'name': 'Viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015658', 'name': 'HIV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106538',
#     'target': 'MESH:C066928',
#     'key': 'INCREASES'},
#    {'source': 'MESH:C066928', 'target': 'UniProt:P04585', 'key': 'INHIBITS'},
#    {'source': 'UniProt:P04585', 'target': 'GO:0039693', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0039693', 'target': 'MESH:D015658', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norethisterone',
#    'disease': 'Menorrhagia',
#    'drugbank': 'DB00717',
#    'drug_mesh': 'MESH:D009640',
#    'disease_mesh': 'MESH:D008595'},
#   'nodes': [{'id': 'MESH:D009640', 'name': 'norethisterone', 'label': 'Drug'},
#    {'id': 'UniProt:P06401',
#     'name': 'progesterone receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P01148',
#     'name': 'gonadotropin releasing hormone',
#     'label': 'Protein'},
#    {'id': 'GO:0032275',
#     'name': 'Luteinizing hormone secretion',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D008595', 'name': 'Menorrhagia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009640',
#     'target': 'UniProt:P06401',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P06401',
#     'target': 'UniProt:P01148',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P01148',
#     'target': 'GO:0032275',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0032275',
#     'target': 'MESH:D008595',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ziprasidone',
#    'disease': 'Schizophrenia',
#    'drugbank': 'DB00246',
#    'drug_mesh': 'MESH:C092292',
#    'disease_mesh': 'MESH:D012559'},
#   'nodes': [{'id': 'MESH:C092292', 'name': 'ziprasidone', 'label': 'Drug'},
#    {'id': 'UniProt:P28223', 'name': '5HT2A receptor', 'label': 'Protein'},
#    {'id': 'HP:0000708', 'name': 'behavior', 'label': 'Phenotype'},
#    {'id': 'MESH:D012559', 'name': 'Schizophrenia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C092292',
#     'target': 'UniProt:P28223',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P28223',
#     'target': 'HP:0000708',
#     'key': 'ASSOCIATED_WITH'},
#    {'source': 'HP:0000708', 'target': 'MESH:D012559', 'key': 'PRESENTED_BY'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'carbinoxamine',
#    'disease': 'seasonal allergic conjunctivitis',
#    'drugbank': 'DB00748',
#    'drug_mesh': 'MESH:C004649',
#    'disease_mesh': 'MESH:D003233'},
#   'nodes': [{'id': 'MESH:C004649', 'name': 'carbinoxamine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003233',
#     'name': 'seasonal allergic conjunctivitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C004649',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0034776', 'target': 'MESH:D003233', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'follitropin',
#    'disease': 'primary ovarian failure',
#    'drugbank': 'DB00066',
#    'drug_mesh': 'MESH:D005640',
#    'disease_mesh': 'MESH:D016649'},
#   'nodes': [{'id': 'MESH:D005640', 'name': 'follitropin', 'label': 'Drug'},
#    {'id': 'UniProt:P23945',
#     'name': 'Human follicle stimulating hormone receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030728', 'name': 'ovulation', 'label': 'Biological Process'},
#    {'id': 'MESH:D016649',
#     'name': 'primary ovarian failure',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005640',
#     'target': 'UniProt:P23945',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P23945', 'target': 'GO:0030728', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030728', 'target': 'MESH:D016649', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftriaxone',
#    'disease': 'Gonorrhea',
#    'drugbank': 'DB01212',
#    'drug_mesh': 'MESH:D002443',
#    'disease_mesh': 'MESH:D006069'},
#   'nodes': [{'id': 'MESH:D002443', 'name': 'ceftriaxone', 'label': 'Drug'},
#    {'id': 'UniProt:O05131',
#     'name': 'Penicillin-binding protein 2B',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:485', 'name': 'N. gonorrhoeae', 'label': 'Taxon'},
#    {'id': 'MESH:D006069', 'name': 'Gonorrhea', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D002443',
#     'target': 'UniProt:O05131',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:O05131', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:485', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:485', 'target': 'MESH:D006069', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fusidic acid',
#    'disease': 'Anthrax',
#    'drugbank': 'DB02703',
#    'drug_mesh': 'MESH:D005672',
#    'disease_mesh': 'MESH:D000881'},
#   'nodes': [{'id': 'MESH:D005672', 'name': 'fusidic acid', 'label': 'Drug'},
#    {'id': 'UniProt:Q81VT3', 'name': 'elongation factor g', 'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1392', 'name': 'Bacillus anthracis', 'label': 'Taxon'},
#    {'id': 'MESH:D000881', 'name': 'Anthrax', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005672',
#     'target': 'UniProt:Q81VT3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q81VT3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:1392', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1392', 'target': 'MESH:D000881', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'warfarin',
#    'disease': 'Pulmonary embolism',
#    'drugbank': 'DB00682',
#    'drug_mesh': 'MESH:D014859',
#    'disease_mesh': 'MESH:D011655'},
#   'nodes': [{'id': 'MESH:D014859', 'name': 'warfarin', 'label': 'Drug'},
#    {'id': 'UniProt:Q9BQB6', 'name': 'vitamin k reductase', 'label': 'Protein'},
#    {'id': 'MESH:D014812', 'name': 'reduced vitamin k', 'label': 'Compound'},
#    {'id': 'GO:0007596',
#     'name': 'Coagulation factor Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D011655', 'name': 'Pulmonary embolism', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D014859',
#     'target': 'UniProt:Q9BQB6',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9BQB6', 'target': 'MESH:D014812', 'key': 'PRODUCES'},
#    {'source': 'MESH:D014812', 'target': 'GO:0007596', 'key': 'PART_OF'},
#    {'source': 'GO:0007596', 'target': 'MESH:D011655', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'metreleptin',
#    'disease': 'lipodystrophy',
#    'drugbank': 'DB09046',
#    'drug_mesh': 'MESH:C415771',
#    'disease_mesh': 'MESH:D008060'},
#   'nodes': [{'id': 'MESH:C415771', 'name': 'metreleptin', 'label': 'Drug'},
#    {'id': 'UniProt:P48357', 'name': 'leptin receptor', 'label': 'Protein'},
#    {'id': 'GO:0060612', 'name': 'adipogenesis', 'label': 'Biological Process'},
#    {'id': 'MESH:D008060', 'name': 'lipodystrophy', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C415771',
#     'target': 'UniProt:P48357',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P48357', 'target': 'GO:0060612', 'key': 'REGULATES'},
#    {'source': 'GO:0060612', 'target': 'MESH:D008060', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftizoxime',
#    'disease': 'Klebsiella cystitis',
#    'drugbank': 'DB01332',
#    'drug_mesh': 'MESH:D015296',
#    'disease_mesh': 'MESH:D007710'},
#   'nodes': [{'id': 'MESH:D015296', 'name': 'ceftizoxime', 'label': 'Drug'},
#    {'id': 'UniProt:P71707',
#     'name': 'Penicillin-binding protein 1A',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:573', 'name': 'Klebsiella pneumoniae', 'label': 'Taxon'},
#    {'id': 'MESH:D007710', 'name': 'Klebsiella cystitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D015296',
#     'target': 'UniProt:P71707',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P71707', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:573', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:573', 'target': 'MESH:D007710', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'loratadine',
#    'disease': 'Allergic Rhinitis',
#    'drugbank': 'DB00455',
#    'drug_mesh': 'MESH:D017336',
#    'disease_mesh': 'MESH:D065631'},
#   'nodes': [{'id': 'MESH:D017336', 'name': 'loratadine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D065631', 'name': 'Allergic Rhinitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D017336',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0034776', 'target': 'MESH:D065631', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'oxymetazoline',
#    'disease': 'Nasal Congestion',
#    'drugbank': 'DB00935',
#    'drug_mesh': 'MESH:D010109',
#    'disease_mesh': 'MESH:D015508'},
#   'nodes': [{'id': 'MESH:D010109', 'name': 'oxymetazoline', 'label': 'Drug'},
#    {'id': 'UniProt:P35348',
#     'name': 'Alpha-1a adrenergic receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0042310',
#     'name': 'Vasoconstriction',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015508', 'name': 'Nasal Congestion', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D010109',
#     'target': 'UniProt:P35348',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P35348', 'target': 'GO:0042310', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0042310', 'target': 'MESH:D015508', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'phenobarbital',
#    'disease': 'Epilepsy',
#    'drugbank': 'DB01174',
#    'drug_mesh': 'MESH:D010634',
#    'disease_mesh': 'MESH:D004827'},
#   'nodes': [{'id': 'MESH:D010634', 'name': 'phenobarbital', 'label': 'Drug'},
#    {'id': 'InterPro:IPR006028',
#     'name': 'GABAA Receptors',
#     'label': 'Protein Family'},
# ...
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'epoetin theta',
#    'disease': 'Anemia',
#    'drugbank': 'DB00016',
#    'drug_mesh': 'MESH:C555712',
#    'disease_mesh': 'MESH:D000740'},
#   'nodes': [{'id': 'MESH:C555712', 'name': 'epoetin theta', 'label': 'Drug'},
#    {'id': 'UniProt:P19235',
#     'name': 'erythropoietin receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030218',
#     'name': 'erythrocyte differentiation',
#     'label': 'Biological Process'},
#    {'id': 'CL:0000232', 'name': 'erythrocytes', 'label': 'Cell Type'},
#    {'id': 'MESH:D000740', 'name': 'Anemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C555712',
#     'target': 'UniProt:P19235',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P19235', 'target': 'GO:0030218', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030218', 'target': 'CL:0000232', 'key': 'PRODUCES'},
#    {'source': 'CL:0000232', 'target': 'MESH:D000740', 'key': 'REDUCED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'sulfasalazine',
#    'disease': 'Ulcerative Colitis',
#    'drugbank': 'DB00795',
#    'drug_mesh': 'MESH:D012460',
#    'disease_mesh': 'MESH:D003093'},
#   'nodes': [{'id': 'MESH:D012460', 'name': 'sulfasalazine', 'label': 'Drug'},
#    {'id': 'UniProt:P09917',
#     'name': 'Arachidonate 5-lipoxygenase',
#     'label': 'Protein'},
#    {'id': 'GO:0019370',
#     'name': 'leukotriene biosynthesis',
#     'label': 'Biological Process'},
#    {'id': 'GO:0006954',
#     'name': 'inflammatory response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003093', 'name': 'Ulcerative Colitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D012460',
#     'target': 'UniProt:P09917',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P09917', 'target': 'GO:0019370', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0019370', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D003093', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'foscarnet',
#    'disease': 'Cytomegalovirus Retinitis',
#    'drugbank': 'DB00529',
#    'drug_mesh': 'MESH:D017245',
#    'disease_mesh': 'MESH:D017726'},
#   'nodes': [{'id': 'MESH:D017245', 'name': 'foscarnet', 'label': 'Drug'},
#    {'id': 'UniProt:P08546',
#     'name': 'viral DNA Polymerase',
#     'label': 'Protein'},
#    {'id': 'GO:0039693',
#     'name': 'viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:10358', 'name': 'Cytomegalovirus', 'label': 'Taxon'},
#    {'id': 'MESH:D017726',
#     'name': 'Cytomegalovirus Retinitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D017245',
#     'target': 'UniProt:P08546',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P08546', 'target': 'GO:0039693', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0039693',
#     'target': 'NCBITaxon:10358',
#     'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:10358', 'target': 'MESH:D017726', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'chlorhexidine',
#    'disease': 'periodontitis',
#    'drugbank': 'DB00878',
#    'drug_mesh': 'MESH:D002710',
#    'disease_mesh': 'MESH:D010518'},
#   'nodes': [{'id': 'MESH:D002710', 'name': 'chlorhexidine', 'label': 'Drug'},
#    {'id': 'GO:0009274',
#     'name': 'Bacterial Cell Wall',
#     'label': 'Cellular Component'},
#    {'id': 'NCBITaxon:837',
#     'name': 'Porphyromonas gingivalis',
#     'label': 'Taxon'},
#    {'id': 'MESH:D010518', 'name': 'periodontitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D002710',
#     'target': 'GO:0009274',
#     'key': 'DISRUPTS'},
#    {'source': 'GO:0009274', 'target': 'NCBITaxon:837', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:837', 'target': 'MESH:D010518', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'pegaspargase',
#    'disease': 'Acute lymphoblastic leukemia',
#    'drugbank': 'DB00059',
#    'drug_mesh': 'MESH:C042705',
#    'disease_mesh': 'MESH:D054198'},
#   'nodes': [{'id': 'MESH:C042705', 'name': 'pegaspargase', 'label': 'Drug'},
#    {'id': 'MESH:D001216',
#     'name': 'extracellular asparagine',
#     'label': 'Compound'},
#    {'id': 'GO:0008283',
#     'name': 'cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D054198',
#     'name': 'Acute lymphoblastic leukemia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C042705',
#     'target': 'MESH:D001216',
#     'key': 'REDUCES'},
#    {'source': 'MESH:D001216', 'target': 'GO:0008283', 'key': 'PART_OF'},
#    {'source': 'GO:0008283', 'target': 'MESH:D054198', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'rifapentine',
#    'disease': 'Pulmonary tuberculosis',
#    'drugbank': 'DB01201',
#    'drug_mesh': 'MESH:C018421',
#    'disease_mesh': 'MESH:D014397'},
#   'nodes': [{'id': 'MESH:C018421', 'name': 'rifapentine', 'label': 'Drug'},
#    {'id': 'UniProt:P9WGY7',
#     'name': 'DNA-directed RNA polymerase subunit beta',
#     'label': 'Protein'},
#    {'id': 'GO:0032774',
#     'name': 'RNA synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1773',
#     'name': 'Mycobacterium tuberculosis infection',
#     'label': 'Taxon'},
#    {'id': 'MESH:D014397',
#     'name': 'Pulmonary tuberculosis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C018421',
#     'target': 'UniProt:P9WGY7',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P9WGY7', 'target': 'GO:0032774', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0032774', 'target': 'NCBITaxon:1773', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1773', 'target': 'MESH:D014397', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'trichloroacetic acid',
#    'disease': 'Condyloma acuminatum',
#    'drugbank': 'DB11152',
#    'drug_mesh': 'MESH:D014238',
#    'disease_mesh': 'MESH:D003218'},
#   'nodes': [{'id': 'MESH:D014238',
#     'name': 'trichloroacetic acid',
#     'label': 'Drug'},
#    {'id': 'GO:0070265',
#     'name': 'necrotic cell death',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003218', 'name': 'Condyloma acuminatum', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D014238',
#     'target': 'GO:0070265',
#     'key': 'ACTIVATES'},
#    {'source': 'GO:0070265', 'target': 'MESH:D003218', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'vinpocetine',
#    'disease': 'Dementia',
#    'drugbank': 'DB12131',
#    'drug_mesh': 'MESH:C013983',
#    'disease_mesh': 'MESH:D003704'},
#   'nodes': [{'id': 'MESH:C013983', 'name': 'vinpocetine', 'label': 'Drug'},
#    {'id': 'UniProt:P54750',
#     'name': "Calcium/calmodulin-dependent 3',5'-cyclic nucleotide phosphodiesterase 1A",
#     'label': 'Protein'},
#    {'id': 'GO:0043025',
#     'name': 'Neuronal Cell Body',
#     'label': 'Cellular Component'},
#    {'id': 'MESH:D003704', 'name': 'Dementia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C013983',
#     'target': 'UniProt:P54750',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P54750', 'target': 'GO:0043025', 'key': 'PART_OF'},
#    {'source': 'GO:0043025',
#     'target': 'MESH:D003704',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'calcium glubionate',
#    'disease': 'Hypocalcemia',
#    'drugbank': 'DB13142',
#    'drug_mesh': 'MESH:C042131',
#    'disease_mesh': 'MESH:D006996'},
#   'nodes': [{'id': 'MESH:C042131',
#     'name': 'calcium glubionate',
#     'label': 'Drug'},
#    {'id': 'MESH:D002118', 'name': 'Calcium Ion', 'label': 'Compound'},
#    {'id': 'MESH:D006996', 'name': 'Hypocalcemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C042131',
#     'target': 'MESH:D002118',
#     'key': 'INCREASES'},
#    {'source': 'MESH:D002118', 'target': 'MESH:D006996', 'key': 'REDUCED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'glutethimide',
#    'disease': 'Insomnia',
#    'drugbank': 'DB01437',
#    'drug_mesh': 'MESH:D005984',
#    'disease_mesh': 'MESH:D007319'},
#   'nodes': [{'id': 'MESH:D005984', 'name': 'glutethimide', 'label': 'Drug'},
#    {'id': 'UniProt:P14867',
#     'name': 'Gamma-aminobutyric acid receptor subunit alpha-1',
#     'label': 'Protein'},
#    {'id': 'GO:1904862',
#     'name': 'inhibitory synapse assembly',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D007319', 'name': 'Insomnia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005984',
#     'target': 'UniProt:P14867',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P14867', 'target': 'GO:1904862', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:1904862',
#     'target': 'MESH:D007319',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fomepizole',
#    'disease': 'Methanol poisoning',
#    'drugbank': 'DB01213',
#    'drug_mesh': 'MESH:D000077604',
#    'disease_mesh': 'MESH:D000138'},
#   'nodes': [{'id': 'MESH:D000077604', 'name': 'fomepizole', 'label': 'Drug'},
#    {'id': 'UniProt:P07327',
#     'name': 'Alcohol dehydrogenase 1A',
#     'label': 'Protein'},
#    {'id': 'REACT:R-HSA-71384',
#     'name': 'Ethanol oxidation',
#     'label': 'Pathway'},
#    {'id': 'MESH:C030544', 'name': 'formic acid', 'label': 'Compound'},
#    {'id': 'MESH:D000138', 'name': 'Methanol poisoning', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000077604',
#     'target': 'UniProt:P07327',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P07327',
#     'target': 'REACT:R-HSA-71384',
#     'key': 'PART_OF'},
#    {'source': 'REACT:R-HSA-71384',
#     'target': 'MESH:C030544',
#     'key': 'PRODUCES'},
#    {'source': 'MESH:C030544', 'target': 'MESH:D000138', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'afamelanotide',
#    'disease': 'erythropoietic protoporphyria',
#    'drugbank': 'DB04931',
#    'drug_mesh': 'MESH:C534526',
#    'disease_mesh': 'MESH:D046351'},
#   'nodes': [{'id': 'MESH:C534526', 'name': 'afamelanotide', 'label': 'Drug'},
#    {'id': 'UniProt:Q01726',
#     'name': 'Melanocyte-stimulating hormone receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0042438',
#     'name': 'melanogenesis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:C041877', 'name': 'eumelanin', 'label': 'Compound'},
#    {'id': 'GO:0009650',
#     'name': 'UV protection',
#     'label': 'Biological Process'},
#    {'id': 'CHEBI:26523',
#     'name': 'reative oxygen species',
#     'label': 'Compound Class'},
#    {'id': 'MESH:C028025', 'name': 'protoporphyrin IX', 'label': 'Compound'},
#    {'id': 'MESH:D046351',
#     'name': 'erythropoietic protoporphyria',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C534526',
#     'target': 'UniProt:Q01726',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q01726', 'target': 'GO:0042438', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042438', 'target': 'MESH:C041877', 'key': 'UP_REGULATES'},
#    {'source': 'MESH:C041877', 'target': 'GO:0009650', 'key': 'PART_OF'},
#    {'source': 'GO:0009650', 'target': 'CHEBI:26523', 'key': 'REDUCES'},
#    {'source': 'CHEBI:26523', 'target': 'MESH:C028025', 'key': 'INCREASED_BY'},
#    {'source': 'MESH:C028025',
#     'target': 'MESH:D046351',
#     'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'voclosporin',
#    'disease': 'Noninfectious Uveitis',
#    'drugbank': 'DB11693',
#    'drug_mesh': 'MESH:C484071',
#    'disease_mesh': 'MESH:D014605'},
#   'nodes': [{'id': 'MESH:C484071', 'name': 'voclosporin', 'label': 'Drug'},
#    {'id': 'UniProt:P63098',
#     'name': 'Calcineurin subunit B type 1',
#     'label': 'Protein'},
#    {'id': 'UniProt:O95644',
#     'name': 'Nuclear factor of activated T-cells, cytoplasmic 1',
#     'label': 'Protein'},
#    {'id': 'UniProt:P60568', 'name': 'interleukin 2', 'label': 'Protein'},
#    {'id': 'CL:0000084', 'name': 'T-Cell', 'label': 'Cell Type'},
#    {'id': 'MESH:D014605',
#     'name': 'Noninfectious Uveitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C484071',
#     'target': 'UniProt:P63098',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P63098',
#     'target': 'UniProt:O95644',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:O95644',
#     'target': 'UniProt:P60568',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P60568', 'target': 'CL:0000084', 'key': 'STIMULATES'},
#    {'source': 'CL:0000084', 'target': 'MESH:D014605', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acrisorcin',
#    'disease': 'Pityriasis versicolor',
#    'drugbank': ', DB11254',
#    'drug_mesh': 'MESH:D000585, MESH:D006604',
#    'disease_mesh': 'MESH:D014010'},
#   'nodes': [{'id': 'MESH:D000585, MESH:D006604',
#     'name': 'acrisorcin',
#     'label': 'Drug'},
#    {'id': 'MESH:D014010',
#     'name': 'Pityriasis versicolor',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000585, MESH:D006604',
#     'target': 'MESH:D014010',
#     'key': 'TREATS'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ivermectin',
#    'disease': 'Onchocerciasis',
#    'drugbank': 'DB00602',
#    'drug_mesh': 'MESH:D007559',
#    'disease_mesh': 'MESH:D009855'},
#   'nodes': [{'id': 'MESH:D007559', 'name': 'ivermectin', 'label': 'Drug'},
#    {'id': 'InterPro:IPR015680',
#     'name': 'glutimate-gated chloride channels',
#     'label': 'Protein Family'},
#    {'id': 'CHEBI:17996', 'name': 'chloride ion', 'label': 'Compound'},
#    {'id': 'GO:0060081',
#     'name': 'membrane hyperpolarization',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D010243', 'name': 'Paralysis', 'label': 'Biological Process'},
#    {'id': 'NCBITaxon:6282', 'name': 'Onchocerca volvulus', 'label': 'Disease'},
#    {'id': 'MESH:D009855', 'name': 'Onchocerciasis', 'label': None}],
#   'links': [{'source': 'MESH:D007559',
#     'target': 'InterPro:IPR015680',
#     'key': 'ACTIVATES'},
#    {'source': 'InterPro:IPR015680',
#     'target': 'CHEBI:17996',
#     'key': 'INCREASES'},
#    {'source': 'CHEBI:17996', 'target': 'GO:0060081', 'key': 'PART_OF'},
#    {'source': 'GO:0060081', 'target': 'MESH:D010243', 'key': 'CAUSES'},
#    {'source': 'MESH:D010243', 'target': 'NCBITaxon:6282', 'key': 'REDUCES'},
#    {'source': 'NCBITaxon:6282', 'target': 'MESH:D009855', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cobicistat',
#    'disease': 'HIV infection',
#    'drugbank': 'DB09065',
#    'drug_mesh': 'MESH:D000069547',
#    'disease_mesh': 'MESH:D015658'},
#   'nodes': [{'id': 'MESH:D000069547', 'name': 'cobicistat', 'label': 'Drug'},
#    {'id': 'UniProt:Q9HB55',
#     'name': 'cytochrome P450 3A (CYP3A) isoforms',
#     'label': 'Protein'},
#    {'id': 'MESH:D000069446', 'name': 'atazanavir', 'label': 'Compound'},
#    {'id': 'UniProt:P04585', 'name': 'Gag-Pol polyprotein', 'label': 'Protein'},
#    {'id': 'GO:0019068',
#     'name': 'Viral Assembly',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015658', 'name': 'HIV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000069547',
#     'target': 'UniProt:Q9HB55',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9HB55', 'target': 'MESH:D000069446', 'key': 'REDUCES'},
#    {'source': 'MESH:D000069446',
#     'target': 'UniProt:P04585',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P04585', 'target': 'GO:0019068', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0019068', 'target': 'MESH:D015658', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'avelumab',
#    'disease': 'Merkel cell carcinoma',
#    'drugbank': 'DB11945',
#    'drug_mesh': 'MESH:C000609138',
#    'disease_mesh': 'MESH:D015266'},
#   'nodes': [{'id': 'MESH:C000609138', 'name': 'avelumab', 'label': 'Drug'},
#    {'id': 'UniProt:Q9NZQ7',
#     'name': 'Programmed cell death 1 ligand 1',
#     'label': 'Protein'},
#    {'id': 'GO:0036037',
#     'name': 'Cytotoxic T-Cell activity',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008283',
#     'name': 'Cell proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015266',
#     'name': 'Merkel cell carcinoma',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C000609138',
#     'target': 'UniProt:Q9NZQ7',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9NZQ7',
#     'target': 'GO:0036037',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0036037', 'target': 'GO:0008283', 'key': 'REDUCES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D015266', 'key': 'ELEVATED_IN'}]}]

# %%
len(data_json) == len(paths)
# Out:
# True

# %% [markdown]
# Let's take a look at an example path:

# %%
data_json[1]
# Out:
# {'directed': True,
#  'multigraph': True,
#  'graph': {'drug': 'imatinib',
#   'disease': 'Systemic mast cell disease',
#   'drugbank': 'DB00619',
#   'drug_mesh': 'MESH:D000068877',
#   'disease_mesh': 'MESH:D034721'},
#  'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#   {'id': 'UniProt:P10721', 'name': 'c-Kit', 'label': 'Protein'},
#   {'id': 'GO:0008283',
#    'name': 'Cellular proliferation',
#    'label': 'Biological Process'},
#   {'id': 'MESH:D034721',
#    'name': 'Systemic mast cell disease',
#    'label': 'Disease'}],
#  'links': [{'source': 'MESH:D000068877',
#    'target': 'UniProt:P10721',
#    'key': 'INHIBITS'},
#   {'source': 'UniProt:P10721', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#   {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]}

# %% [markdown]
# We can get the number of nodes involved:

# %%
len(data_json[1]['nodes'])
# Out:
# 4

# %% [markdown]
# ... and using that, get the second-to-last node (the last is always a disease).

# %%
data_json[1]['nodes'][len(data_json[1]['nodes']) - 2]
# Out:
# {'id': 'GO:0008283',
#  'name': 'Cellular proliferation',
#  'label': 'Biological Process'}

# %% [markdown]
# Cool, let's create a new object containing only those which end in a BP node.
#
# Let's also get all the unique BPs involved:

# %%
bp_paths = []
bp_path_lengths = []
bps = set()
for path in data_json:
    # if second to last node is BP,
    if path['nodes'][len(path['nodes']) - 2]['label'] == 'Biological Process':
        bp_paths.append(path)
        bp_path_lengths.append(len(path['links']) - 1)
        bps.add(path['nodes'][len(path['nodes']) - 2]['id'])

# %% [markdown]
# How many of the 162 paths end in a BP?

# %%
len(bp_paths)
# Out:
# 62

# %%
Counter(bp_path_lengths)
# Out:
# Counter({2: 25, 3: 24, 4: 7, 1: 6})

# %%
bpath_lens = Counter(bp_path_lengths)

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

plt.bar(bpath_lens.keys(), bpath_lens.values())

plt.show()

# %% [markdown]
# Now, it also looks like no paths ending in BP are longer than 5 edges.
#
# How many unique BPs act as sink nodes here?

# %%
len(bps)
# Out:
# 34

# %%
bp_paths[0]
# Out:
# {'directed': True,
#  'multigraph': True,
#  'graph': {'drug': 'imatinib',
#   'disease': 'Systemic mast cell disease',
#   'drugbank': 'DB00619',
#   'drug_mesh': 'MESH:D000068877',
#   'disease_mesh': 'MESH:D034721'},
#  'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#   {'id': 'UniProt:P10721', 'name': 'c-Kit', 'label': 'Protein'},
#   {'id': 'GO:0008283',
#    'name': 'Cellular proliferation',
#    'label': 'Biological Process'},
#   {'id': 'MESH:D034721',
#    'name': 'Systemic mast cell disease',
#    'label': 'Disease'}],
#  'links': [{'source': 'MESH:D000068877',
#    'target': 'UniProt:P10721',
#    'key': 'INHIBITS'},
#   {'source': 'UniProt:P10721', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#   {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]}

# %% [markdown]
# **It is worth noting that there are lots of non-drug compounds in here, such as carbovir triphosphate and prostaglandins, which act as middle players in the paths.**

# %% [markdown]
# What about any path in general which contains a BP?

# %%
bp_paths = []
bp_path_lengths = []
bps = set()
for path in data_json:
    for count, node in enumerate(path['nodes']):
    # if any node is BP,
        if node['label'] == 'Biological Process':
            bp_paths.append(path)
            bp_path_lengths.append(count)
            bps.add(path['nodes'][count]['id'])

# %%
len(bp_paths)
# Out:
# 100

# %% [markdown]
# We have a lot more if we include BPs in the middle.

# %%
Counter(bp_path_lengths)
# Out:
# Counter({2: 60, 3: 25, 4: 9, 1: 6})

# %%
bpath_lens = Counter(bp_path_lengths)

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

plt.bar(bpath_lens.keys(), bpath_lens.values())

plt.show()

# %% [markdown]
# Now, we have a lot more 2-hop mechanisms. These are most likely drug-protein-BP paths.
#
# Also worth noting that 5 of these seem to act directly.

# %% [markdown]
# ## Extracting MOAs for Result Validation
#
# Here, we get these MOAs synchronized with the IDs used in our KG, and then we save them in a file for easy comparison against test results.
#
# First, in the `preprocess_drugmechdb` notebook, we've seen that some of the identifiers need to map to others. We'll use the files which were prepared there to do easy mapping here.

# %%
bp_paths
# Out:
# [{'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'imatinib',
#    'disease': 'Systemic mast cell disease',
#    'drugbank': 'DB00619',
#    'drug_mesh': 'MESH:D000068877',
#    'disease_mesh': 'MESH:D034721'},
#   'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#    {'id': 'UniProt:P10721', 'name': 'c-Kit', 'label': 'Protein'},
#    {'id': 'GO:0008283',
#     'name': 'Cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D034721',
#     'name': 'Systemic mast cell disease',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068877',
#     'target': 'UniProt:P10721',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P10721', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'imatinib',
#    'disease': 'Systemic mast cell disease',
#    'drugbank': 'DB00619',
#    'drug_mesh': 'MESH:D000068877',
#    'disease_mesh': 'MESH:D034721'},
#   'nodes': [{'id': 'MESH:D000068877', 'name': 'imatinib', 'label': 'Drug'},
#    {'id': 'UniProt:P16234', 'name': 'Pdgf', 'label': 'Protein'},
#    {'id': 'GO:0008283',
#     'name': 'Cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D034721',
#     'name': 'Systemic mast cell disease',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068877',
#     'target': 'UniProt:P16234',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P16234', 'target': 'GO:0008283', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D034721', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetaminophen',
#    'disease': 'Fever',
#    'drugbank': 'DB00316',
#    'drug_mesh': 'MESH:D000082',
#    'disease_mesh': 'MESH:D005334'},
#   'nodes': [{'id': 'MESH:D000082', 'name': 'acetaminophen', 'label': 'Drug'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'cycloxygenaze pathways',
#     'label': 'Pathway'},
#    {'id': 'UBERON:0000955', 'name': 'Brain', 'label': 'Anatomy'},
#    {'id': 'GO:0001659',
#     'name': 'Temperature Homeostasis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D005334', 'name': 'Fever', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000082',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'INHIBITS'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'UBERON:0000955',
#     'key': 'LOCALIZED_TO'},
#    {'source': 'UBERON:0000955', 'target': 'GO:0001659', 'key': 'REGULATES'},
#    {'source': 'GO:0001659', 'target': 'MESH:D005334', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Thrombosis',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D013927'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Synthesis of Prostaglandins and Thromboxanes',
#     'label': 'Pathway'},
#    {'id': 'MESH:D013928', 'name': 'Thromboxane A2', 'label': 'Compound'},
#    {'id': 'GO:0007596',
#     'name': 'Platelet Activiation / Blood Coagulation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013927', 'name': 'Thrombosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'PART_OF'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'MESH:D013928',
#     'key': 'PRODUCES'},
#    {'source': 'MESH:D013928', 'target': 'GO:0007596', 'key': 'PART_OF'},
#    {'source': 'GO:0007596', 'target': 'MESH:D013927', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'acetylsalicylic acid',
#    'disease': 'Thrombosis',
#    'drugbank': 'DB00945',
#    'drug_mesh': 'MESH:D001241',
#    'disease_mesh': 'MESH:D013927'},
#   'nodes': [{'id': 'MESH:D001241',
#     'name': 'acetylsalicylic acid',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX', 'label': 'Protein'},
#    {'id': 'GO:0007596',
#     'name': 'Blood Coagulation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013927', 'name': 'Thrombosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D001241',
#     'target': 'UniProt:P23219',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P23219', 'target': 'GO:0007596', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0007596', 'target': 'MESH:D013927', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'naproxen',
#    'disease': 'Pain',
#    'drugbank': 'DB00788',
#    'drug_mesh': 'MESH:D009288',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D009288', 'name': 'naproxen', 'label': 'Drug'},
#    {'id': 'UniProt:P35354', 'name': 'Cox-2', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009288',
#     'target': 'UniProt:P35354',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35354', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D010146', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norfloxacin',
#    'disease': 'Shigellosis',
#    'drugbank': 'DB01059',
#    'drug_mesh': 'MESH:D009643',
#    'disease_mesh': 'MESH:D004405'},
#   'nodes': [{'id': 'MESH:D009643', 'name': 'norfloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P43702',
#     'name': 'topoisomerases II, IV',
#     'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bactierial DNA Replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:622', 'name': 'Shigella dysenteriae', 'label': 'Taxon'},
#    {'id': 'MESH:D004405', 'name': 'Shigellosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009643',
#     'target': 'UniProt:P43702',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P43702', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:622', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:622', 'target': 'MESH:D004405', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norfloxacin',
#    'disease': 'Shigellosis',
#    'drugbank': 'DB01059',
#    'drug_mesh': 'MESH:D009643',
#    'disease_mesh': 'MESH:D004405'},
#   'nodes': [{'id': 'MESH:D009643', 'name': 'norfloxacin', 'label': 'Drug'},
#    {'id': 'GO:0003746',
#     'name': 'Translocation of EF-G',
#     'label': 'Molecular Function'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Protein Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:622', 'name': 'Shigella dysenteriae', 'label': 'Taxon'},
#    {'id': 'MESH:D004405', 'name': 'Shigellosis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009643',
#     'target': 'GO:0003746',
#     'key': 'INHIBITS'},
#    {'source': 'GO:0003746', 'target': 'GO:0006412', 'key': 'REQUIRED_FOR'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:622', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:622', 'target': 'MESH:D004405', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04083', 'name': 'lipocortin-1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04083',
#     'key': 'INCREASES_EXPRESSION'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P23219', 'name': 'COX Genes', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P23219',
#     'key': 'DECREASES_EXPRESSION'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04083', 'name': 'lipocortin-1', 'label': 'Protein'},
#    {'id': 'GO:0050900', 'name': 'Immune Cell Funciton', 'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04083',
#     'key': 'INCREASES_EXPRESSION'},
#    {'source': 'UniProt:P04083',
#     'target': 'GO:0050900',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0050900', 'target': 'GO:0006954', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P04083', 'name': 'Annexin A1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cortisone acetate',
#    'disease': 'Keratitis',
#    'drugbank': 'DB01380',
#    'drug_mesh': 'MESH:D003348',
#    'disease_mesh': 'MESH:D007634'},
#   'nodes': [{'id': 'MESH:D003348',
#     'name': 'cortisone acetate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P23219', 'name': 'COX genes', 'label': 'Protein'},
#    {'id': 'MESH:D011453', 'name': 'Prostaglandins', 'label': 'Compound Class'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007634', 'name': 'Keratitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003348',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P23219',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P23219', 'target': 'MESH:D011453', 'key': 'PRODUCES'},
#    {'source': 'MESH:D011453', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D007634', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'valganciclovir',
#    'disease': 'CMV infection',
#    'drugbank': 'DB01610',
#    'drug_mesh': 'MESH:D000077562',
#    'disease_mesh': 'MESH:D003586'},
#   'nodes': [{'id': 'MESH:D000077562',
#     'name': 'valganciclovir',
#     'label': 'Drug'},
#    {'id': 'MESH:D015774', 'name': 'ganciclovir', 'label': 'Compound'},
#    {'id': 'GO:0039693',
#     'name': 'viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:10358', 'name': 'Cytomegalovirus', 'label': 'Taxon'},
#    {'id': 'MESH:D003586', 'name': 'CMV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000077562',
#     'target': 'MESH:D015774',
#     'key': 'INCREASES'},
#    {'source': 'MESH:D015774', 'target': 'GO:0039693', 'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0039693',
#     'target': 'NCBITaxon:10358',
#     'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:10358', 'target': 'MESH:D003586', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'metronidazole',
#    'disease': 'Bacterial septicemia',
#    'drugbank': 'DB00916',
#    'drug_mesh': 'MESH:D008795',
#    'disease_mesh': 'MESH:D018805'},
#   'nodes': [{'id': 'MESH:D008795', 'name': 'metronidazole', 'label': 'Drug'},
#    {'id': 'MESH:C029371',
#     'name': 'hydroxyethyl oxamic acid',
#     'label': 'Compound'},
#    {'id': 'GO:0003676',
#     'name': 'bacterial Nucleic Acid synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:2', 'name': 'Bacteria', 'label': 'Taxon'},
#    {'id': 'MESH:D018805', 'name': 'Bacterial septicemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D008795',
#     'target': 'MESH:C029371',
#     'key': 'INCREASES'},
#    {'source': 'MESH:C029371', 'target': 'GO:0003676', 'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0003676', 'target': 'NCBITaxon:2', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:2', 'target': 'MESH:D018805', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'demeclocycline',
#    'disease': 'Rickettsialpox',
#    'drugbank': 'DB00618',
#    'drug_mesh': 'MESH:D003707',
#    'disease_mesh': 'MESH:D000073605'},
#   'nodes': [{'id': 'MESH:D003707', 'name': 'demeclocycline', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7S3',
#     'name': '30S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:786', 'name': 'Rickettsia akari', 'label': 'Taxon'},
#    {'id': 'MESH:D000073605', 'name': 'Rickettsialpox', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7S3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7S3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:786', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:786', 'target': 'MESH:D000073605', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'demeclocycline',
#    'disease': 'Rickettsialpox',
#    'drugbank': 'DB00618',
#    'drug_mesh': 'MESH:D003707',
#    'disease_mesh': 'MESH:D000073605'},
#   'nodes': [{'id': 'MESH:D003707', 'name': 'demeclocycline', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7J3',
#     'name': '50S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:786', 'name': 'Rickettsia akari', 'label': 'Taxon'},
#    {'id': 'MESH:D000073605', 'name': 'Rickettsialpox', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003707',
#     'target': 'UniProt:P0A7J3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7J3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:786', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:786', 'target': 'MESH:D000073605', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'amoxicillin',
#    'disease': 'Streptococcal tonsillitis',
#    'drugbank': 'DB01060',
#    'drug_mesh': 'MESH:D000658',
#    'disease_mesh': 'MESH:D014069'},
#   'nodes': [{'id': 'MESH:D000658', 'name': 'amoxicillin', 'label': 'Drug'},
#    {'id': 'UniProt:P71707',
#     'name': 'Penicillin-binding protein 1A',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Peptidoglycan Biosyntheic Process',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1314',
#     'name': 'Streptococcus pyogenes',
#     'label': 'Taxon'},
#    {'id': 'MESH:D014069',
#     'name': 'Streptococcal tonsillitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000658',
#     'target': 'UniProt:P71707',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P71707', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:1314', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1314', 'target': 'MESH:D014069', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'alatrofloxacin',
#    'disease': 'Staphylococcal pneumonia',
#    'drugbank': 'DB09335',
#    'drug_mesh': 'MESH:C106856',
#    'disease_mesh': 'MESH:D011023'},
#   'nodes': [{'id': 'MESH:C106856', 'name': 'alatrofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P0C1U9', 'name': 'Topoisomeraze 4', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1280', 'name': 'Staphylococcus aureus', 'label': 'Taxon'},
#    {'id': 'MESH:D011023',
#     'name': 'Staphylococcal pneumonia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106856',
#     'target': 'UniProt:P0C1U9',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0C1U9', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:1280', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1280', 'target': 'MESH:D011023', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'alatrofloxacin',
#    'disease': 'Staphylococcal pneumonia',
#    'drugbank': 'DB09335',
#    'drug_mesh': 'MESH:C106856',
#    'disease_mesh': 'MESH:D011023'},
#   'nodes': [{'id': 'MESH:C106856', 'name': 'alatrofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P20831', 'name': 'DNA gyrase', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1280', 'name': 'Staphylococcus aureus', 'label': 'Taxon'},
#    {'id': 'MESH:D011023',
#     'name': 'Staphylococcal pneumonia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106856',
#     'target': 'UniProt:P20831',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P20831', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:1280', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1280', 'target': 'MESH:D011023', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'amikacin',
#    'disease': 'Bacterial meningitis',
#    'drugbank': 'DB00479',
#    'drug_mesh': 'MESH:D000583',
#    'disease_mesh': 'MESH:D016920'},
#   'nodes': [{'id': 'MESH:D000583', 'name': 'amikacin', 'label': 'Drug'},
#    {'id': 'UniProt:P0A7S3',
#     'name': '30S Ribosomal Subunit',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:2', 'name': 'Bacteria', 'label': 'Taxon'},
#    {'id': 'MESH:D016920', 'name': 'Bacterial meningitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000583',
#     'target': 'UniProt:P0A7S3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P0A7S3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:2', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:2', 'target': 'MESH:D016920', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'dexamethasone',
#    'disease': 'Tenosynovitis',
#    'drugbank': 'DB01234',
#    'drug_mesh': 'MESH:D003907',
#    'disease_mesh': 'MESH:D013717'},
#   'nodes': [{'id': 'MESH:D003907', 'name': 'dexamethasone', 'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P04083', 'name': 'Annexin A1', 'label': 'Protein'},
#    {'id': 'REACT:R-HSA-2162123',
#     'name': 'Prostaglandin Synthesis',
#     'label': 'Pathway'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D013717', 'name': 'Tenosynovitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D003907',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P04083',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P04083',
#     'target': 'REACT:R-HSA-2162123',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'REACT:R-HSA-2162123',
#     'target': 'GO:0006954',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D013717', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftazidime',
#    'disease': 'Bacterial urinary infection',
#    'drugbank': 'DB00438',
#    'drug_mesh': 'MESH:D002442',
#    'disease_mesh': 'MESH:D014552'},
#   'nodes': [{'id': 'MESH:D002442', 'name': 'ceftazidime', 'label': 'Drug'},
#    {'id': 'UniProt:Q8DR59',
#     'name': 'Penicillin-binding proteins',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:562', 'name': 'Escherichia coli', 'label': 'Taxon'},
#    {'id': 'MESH:D014552',
#     'name': 'Bacterial urinary infection',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D002442',
#     'target': 'UniProt:Q8DR59',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q8DR59', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:562', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:562', 'target': 'MESH:D014552', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'pinacidil',
#    'disease': 'Hypertension',
#    'drugbank': 'DB06762',
#    'drug_mesh': 'MESH:D020110',
#    'disease_mesh': 'MESH:D006973'},
#   'nodes': [{'id': 'MESH:D020110', 'name': 'pinacidil', 'label': 'Drug'},
#    {'id': 'UniProt:Q12791',
#     'name': 'Calcium-activated potassium channel subunit alpha-1',
#     'label': 'Protein'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Negative Regulation of Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D006973', 'name': 'Hypertension', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D020110',
#     'target': 'UniProt:Q12791',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q12791', 'target': 'GO:0042311', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042311', 'target': 'GO:0008217', 'key': 'ASSOCIATED_WITH'},
#    {'source': 'GO:0008217', 'target': 'MESH:D006973', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'pinacidil',
#    'disease': 'Hypertension',
#    'drugbank': 'DB06762',
#    'drug_mesh': 'MESH:D020110',
#    'disease_mesh': 'MESH:D006973'},
#   'nodes': [{'id': 'MESH:D020110', 'name': 'pinacidil', 'label': 'Drug'},
#    {'id': 'UniProt:Q12791',
#     'name': 'Calcium-activated potassium channel subunit alpha-1',
#     'label': 'Protein'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Negative Regulation of Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D006973', 'name': 'Hypertension', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D020110',
#     'target': 'UniProt:Q12791',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q12791', 'target': 'GO:0042311', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042311', 'target': 'GO:0008217', 'key': 'ASSOCIATED_WITH'},
#    {'source': 'GO:0008217', 'target': 'MESH:D006973', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'antazoline',
#    'disease': 'Vasomotor rhinitis',
#    'drugbank': 'DB08799',
#    'drug_mesh': 'MESH:D000865',
#    'disease_mesh': 'MESH:D012223'},
#   'nodes': [{'id': 'MESH:D000865', 'name': 'antazoline', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D012223', 'name': 'Vasomotor rhinitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000865',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0034776', 'target': 'MESH:D012223', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'levofloxacin',
#    'disease': 'Pyelonephritis',
#    'drugbank': 'DB01137',
#    'drug_mesh': 'MESH:D064704',
#    'disease_mesh': 'MESH:D011704'},
#   'nodes': [{'id': 'MESH:D064704', 'name': 'levofloxacin', 'label': 'Drug'},
#    {'id': 'UniProt:P11388', 'name': 'DNA gyrase', 'label': 'Protein'},
#    {'id': 'GO:0006260',
#     'name': 'Bacterial DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:562', 'name': 'E. coli', 'label': 'Taxon'},
#    {'id': 'MESH:D011704', 'name': 'Pyelonephritis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D064704',
#     'target': 'UniProt:P11388',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P11388', 'target': 'GO:0006260', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006260', 'target': 'NCBITaxon:562', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:562', 'target': 'MESH:D011704', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'nimodipine',
#    'disease': 'Subarachnoid intracranial hemorrhage',
#    'drugbank': 'DB00393',
#    'drug_mesh': 'MESH:D009553',
#    'disease_mesh': 'MESH:D020300'},
#   'nodes': [{'id': 'MESH:D009553', 'name': 'nimodipine', 'label': 'Drug'},
#    {'id': 'InterPro:IPR005446',
#     'name': 'voltage dependent l-type calcium channels',
#     'label': 'Protein Family'},
#    {'id': 'GO:0006939',
#     'name': 'Smooth muscle contraction',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013345',
#     'name': 'Subarachnoid intracranial hemorrhage',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009553',
#     'target': 'InterPro:IPR005446',
#     'key': 'INHIBITS'},
#    {'source': 'InterPro:IPR005446',
#     'target': 'GO:0006939',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006939', 'target': 'GO:0008217', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008217', 'target': 'MESH:D013345', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'nimodipine',
#    'disease': 'Subarachnoid intracranial hemorrhage',
#    'drugbank': 'DB00393',
#    'drug_mesh': 'MESH:D009553',
#    'disease_mesh': 'MESH:D020300'},
#   'nodes': [{'id': 'MESH:D009553', 'name': 'nimodipine', 'label': 'Drug'},
#    {'id': 'InterPro:IPR005446',
#     'name': 'voltage dependent l-type calcium channels',
#     'label': 'Protein Family'},
#    {'id': 'GO:0006939',
#     'name': 'Smooth muscle contraction',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D013345',
#     'name': 'Subarachnoid intracranial hemorrhage',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009553',
#     'target': 'InterPro:IPR005446',
#     'key': 'INHIBITS'},
#    {'source': 'InterPro:IPR005446',
#     'target': 'GO:0006939',
#     'key': 'UP_REGULATES'},
#    {'source': 'GO:0006939', 'target': 'GO:0008217', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0008217', 'target': 'MESH:D013345', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluticasone propionate',
#    'disease': 'Bronchitis',
#    'drugbank': 'DB00588',
#    'drug_mesh': 'MESH:D000068298',
#    'disease_mesh': 'MESH:D001991'},
#   'nodes': [{'id': 'MESH:D000068298',
#     'name': 'fluticasone propionate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P47712', 'name': 'Phospholipase A2', 'label': 'Protein'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D001991', 'name': 'Bronchitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068298',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P47712',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P47712', 'target': 'GO:0006954', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D001991', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluticasone propionate',
#    'disease': 'Bronchitis',
#    'drugbank': 'DB00588',
#    'drug_mesh': 'MESH:D000068298',
#    'disease_mesh': 'MESH:D001991'},
#   'nodes': [{'id': 'MESH:D000068298',
#     'name': 'fluticasone propionate',
#     'label': 'Drug'},
#    {'id': 'UniProt:P04150',
#     'name': 'Glucocorticoid receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P22301', 'name': 'IL-10', 'label': 'Protein'},
#    {'id': 'GO:0006954', 'name': 'Inflammation', 'label': 'Biological Process'},
#    {'id': 'MESH:D001991', 'name': 'Bronchitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068298',
#     'target': 'UniProt:P04150',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P04150',
#     'target': 'UniProt:P22301',
#     'key': 'UP_REGULATES'},
#    {'source': 'UniProt:P22301',
#     'target': 'GO:0006954',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0006954', 'target': 'MESH:D001991', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fluphenazine',
#    'disease': 'Schizophrenia',
#    'drugbank': 'DB00623',
#    'drug_mesh': 'MESH:D005476',
#    'disease_mesh': 'MESH:D012559'},
#   'nodes': [{'id': 'MESH:D005476', 'name': 'fluphenazine', 'label': 'Drug'},
#    {'id': 'UniProt:P14416',
#     'name': 'D(2) dopamine receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030252',
#     'name': 'growth hormone secretion',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D012559', 'name': 'Schizophrenia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005476',
#     'target': 'UniProt:P14416',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P14416', 'target': 'GO:0030252', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030252', 'target': 'MESH:D012559', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'abacavir',
#    'disease': 'HIV infection',
#    'drugbank': 'DB01048',
#    'drug_mesh': 'MESH:C106538',
#    'disease_mesh': 'MESH:D015658'},
#   'nodes': [{'id': 'MESH:C106538', 'name': 'abacavir', 'label': 'Drug'},
#    {'id': 'MESH:C066928',
#     'name': 'carbovir triphosphate',
#     'label': 'Compound'},
#    {'id': 'UniProt:P04585',
#     'name': 'HIV-1 reverse transcriptase',
#     'label': 'Protein'},
#    {'id': 'GO:0039693',
#     'name': 'Viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015658', 'name': 'HIV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C106538',
#     'target': 'MESH:C066928',
#     'key': 'INCREASES'},
#    {'source': 'MESH:C066928', 'target': 'UniProt:P04585', 'key': 'INHIBITS'},
#    {'source': 'UniProt:P04585', 'target': 'GO:0039693', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0039693', 'target': 'MESH:D015658', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'norethisterone',
#    'disease': 'Menorrhagia',
#    'drugbank': 'DB00717',
#    'drug_mesh': 'MESH:D009640',
#    'disease_mesh': 'MESH:D008595'},
#   'nodes': [{'id': 'MESH:D009640', 'name': 'norethisterone', 'label': 'Drug'},
#    {'id': 'UniProt:P06401',
#     'name': 'progesterone receptor',
#     'label': 'Protein'},
#    {'id': 'UniProt:P01148',
#     'name': 'gonadotropin releasing hormone',
#     'label': 'Protein'},
#    {'id': 'GO:0032275',
#     'name': 'Luteinizing hormone secretion',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D008595', 'name': 'Menorrhagia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D009640',
#     'target': 'UniProt:P06401',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P06401',
#     'target': 'UniProt:P01148',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'UniProt:P01148',
#     'target': 'GO:0032275',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0032275',
#     'target': 'MESH:D008595',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'carbinoxamine',
#    'disease': 'seasonal allergic conjunctivitis',
#    'drugbank': 'DB00748',
#    'drug_mesh': 'MESH:C004649',
#    'disease_mesh': 'MESH:D003233'},
#   'nodes': [{'id': 'MESH:C004649', 'name': 'carbinoxamine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003233',
#     'name': 'seasonal allergic conjunctivitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C004649',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0034776', 'target': 'MESH:D003233', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'follitropin',
#    'disease': 'primary ovarian failure',
#    'drugbank': 'DB00066',
#    'drug_mesh': 'MESH:D005640',
#    'disease_mesh': 'MESH:D016649'},
#   'nodes': [{'id': 'MESH:D005640', 'name': 'follitropin', 'label': 'Drug'},
#    {'id': 'UniProt:P23945',
#     'name': 'Human follicle stimulating hormone receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030728', 'name': 'ovulation', 'label': 'Biological Process'},
#    {'id': 'MESH:D016649',
#     'name': 'primary ovarian failure',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005640',
#     'target': 'UniProt:P23945',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P23945', 'target': 'GO:0030728', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030728', 'target': 'MESH:D016649', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftriaxone',
#    'disease': 'Gonorrhea',
#    'drugbank': 'DB01212',
#    'drug_mesh': 'MESH:D002443',
#    'disease_mesh': 'MESH:D006069'},
#   'nodes': [{'id': 'MESH:D002443', 'name': 'ceftriaxone', 'label': 'Drug'},
#    {'id': 'UniProt:O05131',
#     'name': 'Penicillin-binding protein 2B',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:485', 'name': 'N. gonorrhoeae', 'label': 'Taxon'},
#    {'id': 'MESH:D006069', 'name': 'Gonorrhea', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D002443',
#     'target': 'UniProt:O05131',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:O05131', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:485', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:485', 'target': 'MESH:D006069', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'fusidic acid',
#    'disease': 'Anthrax',
#    'drugbank': 'DB02703',
#    'drug_mesh': 'MESH:D005672',
#    'disease_mesh': 'MESH:D000881'},
#   'nodes': [{'id': 'MESH:D005672', 'name': 'fusidic acid', 'label': 'Drug'},
#    {'id': 'UniProt:Q81VT3', 'name': 'elongation factor g', 'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1392', 'name': 'Bacillus anthracis', 'label': 'Taxon'},
#    {'id': 'MESH:D000881', 'name': 'Anthrax', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005672',
#     'target': 'UniProt:Q81VT3',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q81VT3', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:1392', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1392', 'target': 'MESH:D000881', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'warfarin',
#    'disease': 'Pulmonary embolism',
#    'drugbank': 'DB00682',
#    'drug_mesh': 'MESH:D014859',
#    'disease_mesh': 'MESH:D011655'},
#   'nodes': [{'id': 'MESH:D014859', 'name': 'warfarin', 'label': 'Drug'},
#    {'id': 'UniProt:Q9BQB6', 'name': 'vitamin k reductase', 'label': 'Protein'},
#    {'id': 'MESH:D014812', 'name': 'reduced vitamin k', 'label': 'Compound'},
#    {'id': 'GO:0007596',
#     'name': 'Coagulation factor Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D011655', 'name': 'Pulmonary embolism', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D014859',
#     'target': 'UniProt:Q9BQB6',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9BQB6', 'target': 'MESH:D014812', 'key': 'PRODUCES'},
#    {'source': 'MESH:D014812', 'target': 'GO:0007596', 'key': 'PART_OF'},
#    {'source': 'GO:0007596', 'target': 'MESH:D011655', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'metreleptin',
#    'disease': 'lipodystrophy',
#    'drugbank': 'DB09046',
#    'drug_mesh': 'MESH:C415771',
#    'disease_mesh': 'MESH:D008060'},
#   'nodes': [{'id': 'MESH:C415771', 'name': 'metreleptin', 'label': 'Drug'},
#    {'id': 'UniProt:P48357', 'name': 'leptin receptor', 'label': 'Protein'},
#    {'id': 'GO:0060612', 'name': 'adipogenesis', 'label': 'Biological Process'},
#    {'id': 'MESH:D008060', 'name': 'lipodystrophy', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C415771',
#     'target': 'UniProt:P48357',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P48357', 'target': 'GO:0060612', 'key': 'REGULATES'},
#    {'source': 'GO:0060612', 'target': 'MESH:D008060', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ceftizoxime',
#    'disease': 'Klebsiella cystitis',
#    'drugbank': 'DB01332',
#    'drug_mesh': 'MESH:D015296',
#    'disease_mesh': 'MESH:D007710'},
#   'nodes': [{'id': 'MESH:D015296', 'name': 'ceftizoxime', 'label': 'Drug'},
#    {'id': 'UniProt:P71707',
#     'name': 'Penicillin-binding protein 1A',
#     'label': 'Protein'},
#    {'id': 'GO:0009252',
#     'name': 'Bacterial Cell Wall Synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:573', 'name': 'Klebsiella pneumoniae', 'label': 'Taxon'},
#    {'id': 'MESH:D007710', 'name': 'Klebsiella cystitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D015296',
#     'target': 'UniProt:P71707',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P71707', 'target': 'GO:0009252', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0009252', 'target': 'NCBITaxon:573', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:573', 'target': 'MESH:D007710', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'loratadine',
#    'disease': 'Allergic Rhinitis',
#    'drugbank': 'DB00455',
#    'drug_mesh': 'MESH:D017336',
#    'disease_mesh': 'MESH:D065631'},
#   'nodes': [{'id': 'MESH:D017336', 'name': 'loratadine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D065631', 'name': 'Allergic Rhinitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D017336',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0034776', 'target': 'MESH:D065631', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'oxymetazoline',
#    'disease': 'Nasal Congestion',
#    'drugbank': 'DB00935',
#    'drug_mesh': 'MESH:D010109',
#    'disease_mesh': 'MESH:D015508'},
#   'nodes': [{'id': 'MESH:D010109', 'name': 'oxymetazoline', 'label': 'Drug'},
#    {'id': 'UniProt:P35348',
#     'name': 'Alpha-1a adrenergic receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0042310',
#     'name': 'Vasoconstriction',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015508', 'name': 'Nasal Congestion', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D010109',
#     'target': 'UniProt:P35348',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P35348', 'target': 'GO:0042310', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0042310', 'target': 'MESH:D015508', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'phenobarbital',
#    'disease': 'Epilepsy',
#    'drugbank': 'DB01174',
#    'drug_mesh': 'MESH:D010634',
#    'disease_mesh': 'MESH:D004827'},
#   'nodes': [{'id': 'MESH:D010634', 'name': 'phenobarbital', 'label': 'Drug'},
#    {'id': 'InterPro:IPR006028',
#     'name': 'GABAA Receptors',
#     'label': 'Protein Family'},
#    {'id': 'GO:0099536',
#     'name': 'Synaptic Signaling',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D004827', 'name': 'Epilepsy', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D010634',
#     'target': 'InterPro:IPR006028',
#     'key': 'ACTIVATES'},
#    {'source': 'InterPro:IPR006028',
#     'target': 'GO:0099536',
#     'key': 'INVOLVED_IN'},
#    {'source': 'GO:0099536', 'target': 'MESH:D004827', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'lidocaine',
#    'disease': 'Pain',
#    'drugbank': 'DB00281',
#    'drug_mesh': 'MESH:D008012',
#    'disease_mesh': 'MESH:D010146'},
#   'nodes': [{'id': 'MESH:D008012', 'name': 'lidocaine', 'label': 'Drug'},
#    {'id': 'InterPro:IPR028809',
#     'name': 'Neuronal Voltage gated sodium channels',
#     'label': 'Protein Family'},
#    {'id': 'GO:0019233 ',
#     'name': 'Sensory perception of pain',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D010146', 'name': 'Pain', 'label': 'Disease'},
#    {'id': None, 'name': 'Pain', 'label': None}],
#   'links': [{'source': 'MESH:D008012',
#     'target': 'InterPro:IPR028809',
#     'key': 'INHIBITS'},
#    {'source': 'InterPro:IPR028809',
#     'target': 'GO:0019233 ',
#     'key': 'INVOLVED_IN'},
#    {'source': 'GO:0019233 ', 'target': 'MESH:D010146', 'key': 'CAUSES'},
#    {'source': 'MESH:D010146', 'target': None, 'key': None}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'duloxetine',
#    'disease': 'major depressive disorder',
#    'drugbank': 'DB00476',
#    'drug_mesh': 'MESH:D000068736',
#    'disease_mesh': 'MESH:D003865'},
#   'nodes': [{'id': 'MESH:D000068736', 'name': 'duloxetine', 'label': 'Drug'},
#    {'id': 'UniProt:P31645',
#     'name': 'sodium dependent serotonin transporter',
#     'label': 'Protein'},
#    {'id': 'GO:0051610',
#     'name': 'Neuronal serotonin reuptake',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003865',
#     'name': 'major depressive disorder',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068736',
#     'target': 'UniProt:P31645',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P31645', 'target': 'GO:0051610', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0051610', 'target': 'MESH:D003865', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'doxylamine',
#    'disease': 'Allergic Rhinitis',
#    'drugbank': 'DB00366',
#    'drug_mesh': 'MESH:D004319',
#    'disease_mesh': 'MESH:D065631'},
#   'nodes': [{'id': 'MESH:D004319', 'name': 'doxylamine', 'label': 'Drug'},
#    {'id': 'UniProt:P35367',
#     'name': 'histamine H1 Receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0034776',
#     'name': 'histamine response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D065631', 'name': 'Allergic Rhinitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D004319',
#     'target': 'UniProt:P35367',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P35367', 'target': 'GO:0034776', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0034776', 'target': 'MESH:D065631', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'clarithromycin',
#    'disease': 'Acute maxillary sinusitis',
#    'drugbank': 'DB01211',
#    'drug_mesh': 'MESH:D017291',
#    'disease_mesh': 'MESH:D015523'},
#   'nodes': [{'id': 'MESH:D017291', 'name': 'clarithromycin', 'label': 'Drug'},
#    {'id': 'UniProt:P44350',
#     'name': '50S Ribosomal protein l-10',
#     'label': 'Protein'},
#    {'id': 'GO:0006412',
#     'name': 'Bacterial Translation',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:727', 'name': 'Haemophilus influenzae', 'label': 'Taxon'},
#    {'id': 'MESH:D015523',
#     'name': 'Acute maxillary sinusitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D017291',
#     'target': 'UniProt:P44350',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P44350', 'target': 'GO:0006412', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0006412', 'target': 'NCBITaxon:727', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:727', 'target': 'MESH:D015523', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'minoxidil',
#    'disease': 'Hypertension',
#    'drugbank': 'DB00350',
#    'drug_mesh': 'MESH:D008914',
#    'disease_mesh': 'MESH:D006973'},
#   'nodes': [{'id': 'MESH:D008914', 'name': 'minoxidil', 'label': 'Drug'},
#    {'id': 'UniProt:P48048',
#     'name': 'ATP-sensitive inward rectifier potassium channel 1',
#     'label': 'Protein'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D006973', 'name': 'Hypertension', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D008914',
#     'target': 'UniProt:P48048',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P48048', 'target': 'GO:0042311', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042311', 'target': 'GO:0008217', 'key': 'REDUCES'},
#    {'source': 'GO:0008217', 'target': 'MESH:D006973', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'minoxidil',
#    'disease': 'Hypertension',
#    'drugbank': 'DB00350',
#    'drug_mesh': 'MESH:D008914',
#    'disease_mesh': 'MESH:D006973'},
#   'nodes': [{'id': 'MESH:D008914', 'name': 'minoxidil', 'label': 'Drug'},
#    {'id': 'UniProt:P48048',
#     'name': 'ATP-sensitive inward rectifier potassium channel 1',
#     'label': 'Protein'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'GO:0008217',
#     'name': 'Blood Pressure',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D006973', 'name': 'Hypertension', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D008914',
#     'target': 'UniProt:P48048',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P48048', 'target': 'GO:0042311', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042311', 'target': 'GO:0008217', 'key': 'REDUCES'},
#    {'source': 'GO:0008217', 'target': 'MESH:D006973', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'sildenafil',
#    'disease': 'Erectile Disfunction',
#    'drugbank': 'DB00203',
#    'drug_mesh': 'MESH:D000068677',
#    'disease_mesh': 'MESH:D007172'},
#   'nodes': [{'id': 'MESH:D000068677', 'name': 'sildenafil', 'label': 'Drug'},
#    {'id': 'UniProt:O76074',
#     'name': 'phosphodisterase type 5',
#     'label': 'Protein'},
#    {'id': 'MESH:D006152', 'name': 'cGMP', 'label': 'Compound'},
#    {'id': 'GO:0042311', 'name': 'Vasodilation', 'label': 'Biological Process'},
#    {'id': 'MESH:D007172', 'name': 'Erectile Disfunction', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000068677',
#     'target': 'UniProt:O76074',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:O76074', 'target': 'MESH:D006152', 'key': 'REDUCES'},
#    {'source': 'MESH:D006152', 'target': 'GO:0042311', 'key': 'PART_OF'},
#    {'source': 'GO:0042311', 'target': 'MESH:D007172', 'key': 'DISRUPTED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'gemifloxacin',
#    'disease': 'Bacterial pneumonia',
#    'drugbank': 'DB01155',
#    'drug_mesh': 'MESH:D000077735',
#    'disease_mesh': 'MESH:D018410'},
# ...
#     'target': 'GO:0042060',
#     'key': 'ACTIVATES'},
#    {'source': 'GO:0042060', 'target': 'MESH:D012628', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'epoetin theta',
#    'disease': 'Anemia',
#    'drugbank': 'DB00016',
#    'drug_mesh': 'MESH:C555712',
#    'disease_mesh': 'MESH:D000740'},
#   'nodes': [{'id': 'MESH:C555712', 'name': 'epoetin theta', 'label': 'Drug'},
#    {'id': 'UniProt:P19235',
#     'name': 'erythropoietin receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0030218',
#     'name': 'erythrocyte differentiation',
#     'label': 'Biological Process'},
#    {'id': 'CL:0000232', 'name': 'erythrocytes', 'label': 'Cell Type'},
#    {'id': 'MESH:D000740', 'name': 'Anemia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:C555712',
#     'target': 'UniProt:P19235',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P19235', 'target': 'GO:0030218', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0030218', 'target': 'CL:0000232', 'key': 'PRODUCES'},
#    {'source': 'CL:0000232', 'target': 'MESH:D000740', 'key': 'REDUCED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'sulfasalazine',
#    'disease': 'Ulcerative Colitis',
#    'drugbank': 'DB00795',
#    'drug_mesh': 'MESH:D012460',
#    'disease_mesh': 'MESH:D003093'},
#   'nodes': [{'id': 'MESH:D012460', 'name': 'sulfasalazine', 'label': 'Drug'},
#    {'id': 'UniProt:P09917',
#     'name': 'Arachidonate 5-lipoxygenase',
#     'label': 'Protein'},
#    {'id': 'GO:0019370',
#     'name': 'leukotriene biosynthesis',
#     'label': 'Biological Process'},
#    {'id': 'GO:0006954',
#     'name': 'inflammatory response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003093', 'name': 'Ulcerative Colitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D012460',
#     'target': 'UniProt:P09917',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P09917', 'target': 'GO:0019370', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0019370', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D003093', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'sulfasalazine',
#    'disease': 'Ulcerative Colitis',
#    'drugbank': 'DB00795',
#    'drug_mesh': 'MESH:D012460',
#    'disease_mesh': 'MESH:D003093'},
#   'nodes': [{'id': 'MESH:D012460', 'name': 'sulfasalazine', 'label': 'Drug'},
#    {'id': 'UniProt:P09917',
#     'name': 'Arachidonate 5-lipoxygenase',
#     'label': 'Protein'},
#    {'id': 'GO:0019370',
#     'name': 'leukotriene biosynthesis',
#     'label': 'Biological Process'},
#    {'id': 'GO:0006954',
#     'name': 'inflammatory response',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003093', 'name': 'Ulcerative Colitis', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D012460',
#     'target': 'UniProt:P09917',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P09917', 'target': 'GO:0019370', 'key': 'UP_REGULATES'},
#    {'source': 'GO:0019370', 'target': 'GO:0006954', 'key': 'PART_OF'},
#    {'source': 'GO:0006954', 'target': 'MESH:D003093', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'foscarnet',
#    'disease': 'Cytomegalovirus Retinitis',
#    'drugbank': 'DB00529',
#    'drug_mesh': 'MESH:D017245',
#    'disease_mesh': 'MESH:D017726'},
#   'nodes': [{'id': 'MESH:D017245', 'name': 'foscarnet', 'label': 'Drug'},
#    {'id': 'UniProt:P08546',
#     'name': 'viral DNA Polymerase',
#     'label': 'Protein'},
#    {'id': 'GO:0039693',
#     'name': 'viral DNA replication',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:10358', 'name': 'Cytomegalovirus', 'label': 'Taxon'},
#    {'id': 'MESH:D017726',
#     'name': 'Cytomegalovirus Retinitis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:D017245',
#     'target': 'UniProt:P08546',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P08546', 'target': 'GO:0039693', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0039693',
#     'target': 'NCBITaxon:10358',
#     'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:10358', 'target': 'MESH:D017726', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'pegaspargase',
#    'disease': 'Acute lymphoblastic leukemia',
#    'drugbank': 'DB00059',
#    'drug_mesh': 'MESH:C042705',
#    'disease_mesh': 'MESH:D054198'},
#   'nodes': [{'id': 'MESH:C042705', 'name': 'pegaspargase', 'label': 'Drug'},
#    {'id': 'MESH:D001216',
#     'name': 'extracellular asparagine',
#     'label': 'Compound'},
#    {'id': 'GO:0008283',
#     'name': 'cellular proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D054198',
#     'name': 'Acute lymphoblastic leukemia',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C042705',
#     'target': 'MESH:D001216',
#     'key': 'REDUCES'},
#    {'source': 'MESH:D001216', 'target': 'GO:0008283', 'key': 'PART_OF'},
#    {'source': 'GO:0008283', 'target': 'MESH:D054198', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'rifapentine',
#    'disease': 'Pulmonary tuberculosis',
#    'drugbank': 'DB01201',
#    'drug_mesh': 'MESH:C018421',
#    'disease_mesh': 'MESH:D014397'},
#   'nodes': [{'id': 'MESH:C018421', 'name': 'rifapentine', 'label': 'Drug'},
#    {'id': 'UniProt:P9WGY7',
#     'name': 'DNA-directed RNA polymerase subunit beta',
#     'label': 'Protein'},
#    {'id': 'GO:0032774',
#     'name': 'RNA synthesis',
#     'label': 'Biological Process'},
#    {'id': 'NCBITaxon:1773',
#     'name': 'Mycobacterium tuberculosis infection',
#     'label': 'Taxon'},
#    {'id': 'MESH:D014397',
#     'name': 'Pulmonary tuberculosis',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C018421',
#     'target': 'UniProt:P9WGY7',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P9WGY7', 'target': 'GO:0032774', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0032774', 'target': 'NCBITaxon:1773', 'key': 'REQUIRED_FOR'},
#    {'source': 'NCBITaxon:1773', 'target': 'MESH:D014397', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'trichloroacetic acid',
#    'disease': 'Condyloma acuminatum',
#    'drugbank': 'DB11152',
#    'drug_mesh': 'MESH:D014238',
#    'disease_mesh': 'MESH:D003218'},
#   'nodes': [{'id': 'MESH:D014238',
#     'name': 'trichloroacetic acid',
#     'label': 'Drug'},
#    {'id': 'GO:0070265',
#     'name': 'necrotic cell death',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D003218', 'name': 'Condyloma acuminatum', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D014238',
#     'target': 'GO:0070265',
#     'key': 'ACTIVATES'},
#    {'source': 'GO:0070265', 'target': 'MESH:D003218', 'key': 'REDUCES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'glutethimide',
#    'disease': 'Insomnia',
#    'drugbank': 'DB01437',
#    'drug_mesh': 'MESH:D005984',
#    'disease_mesh': 'MESH:D007319'},
#   'nodes': [{'id': 'MESH:D005984', 'name': 'glutethimide', 'label': 'Drug'},
#    {'id': 'UniProt:P14867',
#     'name': 'Gamma-aminobutyric acid receptor subunit alpha-1',
#     'label': 'Protein'},
#    {'id': 'GO:1904862',
#     'name': 'inhibitory synapse assembly',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D007319', 'name': 'Insomnia', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D005984',
#     'target': 'UniProt:P14867',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:P14867', 'target': 'GO:1904862', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:1904862',
#     'target': 'MESH:D007319',
#     'key': 'ASSOCIATED_WITH'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'afamelanotide',
#    'disease': 'erythropoietic protoporphyria',
#    'drugbank': 'DB04931',
#    'drug_mesh': 'MESH:C534526',
#    'disease_mesh': 'MESH:D046351'},
#   'nodes': [{'id': 'MESH:C534526', 'name': 'afamelanotide', 'label': 'Drug'},
#    {'id': 'UniProt:Q01726',
#     'name': 'Melanocyte-stimulating hormone receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0042438',
#     'name': 'melanogenesis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:C041877', 'name': 'eumelanin', 'label': 'Compound'},
#    {'id': 'GO:0009650',
#     'name': 'UV protection',
#     'label': 'Biological Process'},
#    {'id': 'CHEBI:26523',
#     'name': 'reative oxygen species',
#     'label': 'Compound Class'},
#    {'id': 'MESH:C028025', 'name': 'protoporphyrin IX', 'label': 'Compound'},
#    {'id': 'MESH:D046351',
#     'name': 'erythropoietic protoporphyria',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C534526',
#     'target': 'UniProt:Q01726',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q01726', 'target': 'GO:0042438', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042438', 'target': 'MESH:C041877', 'key': 'UP_REGULATES'},
#    {'source': 'MESH:C041877', 'target': 'GO:0009650', 'key': 'PART_OF'},
#    {'source': 'GO:0009650', 'target': 'CHEBI:26523', 'key': 'REDUCES'},
#    {'source': 'CHEBI:26523', 'target': 'MESH:C028025', 'key': 'INCREASED_BY'},
#    {'source': 'MESH:C028025',
#     'target': 'MESH:D046351',
#     'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'afamelanotide',
#    'disease': 'erythropoietic protoporphyria',
#    'drugbank': 'DB04931',
#    'drug_mesh': 'MESH:C534526',
#    'disease_mesh': 'MESH:D046351'},
#   'nodes': [{'id': 'MESH:C534526', 'name': 'afamelanotide', 'label': 'Drug'},
#    {'id': 'UniProt:Q01726',
#     'name': 'Melanocyte-stimulating hormone receptor',
#     'label': 'Protein'},
#    {'id': 'GO:0042438',
#     'name': 'melanogenesis',
#     'label': 'Biological Process'},
#    {'id': 'MESH:C041877', 'name': 'eumelanin', 'label': 'Compound'},
#    {'id': 'GO:0009650',
#     'name': 'UV protection',
#     'label': 'Biological Process'},
#    {'id': 'CHEBI:26523',
#     'name': 'reative oxygen species',
#     'label': 'Compound Class'},
#    {'id': 'MESH:C028025', 'name': 'protoporphyrin IX', 'label': 'Compound'},
#    {'id': 'MESH:D046351',
#     'name': 'erythropoietic protoporphyria',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C534526',
#     'target': 'UniProt:Q01726',
#     'key': 'ACTIVATES'},
#    {'source': 'UniProt:Q01726', 'target': 'GO:0042438', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0042438', 'target': 'MESH:C041877', 'key': 'UP_REGULATES'},
#    {'source': 'MESH:C041877', 'target': 'GO:0009650', 'key': 'PART_OF'},
#    {'source': 'GO:0009650', 'target': 'CHEBI:26523', 'key': 'REDUCES'},
#    {'source': 'CHEBI:26523', 'target': 'MESH:C028025', 'key': 'INCREASED_BY'},
#    {'source': 'MESH:C028025',
#     'target': 'MESH:D046351',
#     'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ivermectin',
#    'disease': 'Onchocerciasis',
#    'drugbank': 'DB00602',
#    'drug_mesh': 'MESH:D007559',
#    'disease_mesh': 'MESH:D009855'},
#   'nodes': [{'id': 'MESH:D007559', 'name': 'ivermectin', 'label': 'Drug'},
#    {'id': 'InterPro:IPR015680',
#     'name': 'glutimate-gated chloride channels',
#     'label': 'Protein Family'},
#    {'id': 'CHEBI:17996', 'name': 'chloride ion', 'label': 'Compound'},
#    {'id': 'GO:0060081',
#     'name': 'membrane hyperpolarization',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D010243', 'name': 'Paralysis', 'label': 'Biological Process'},
#    {'id': 'NCBITaxon:6282', 'name': 'Onchocerca volvulus', 'label': 'Disease'},
#    {'id': 'MESH:D009855', 'name': 'Onchocerciasis', 'label': None}],
#   'links': [{'source': 'MESH:D007559',
#     'target': 'InterPro:IPR015680',
#     'key': 'ACTIVATES'},
#    {'source': 'InterPro:IPR015680',
#     'target': 'CHEBI:17996',
#     'key': 'INCREASES'},
#    {'source': 'CHEBI:17996', 'target': 'GO:0060081', 'key': 'PART_OF'},
#    {'source': 'GO:0060081', 'target': 'MESH:D010243', 'key': 'CAUSES'},
#    {'source': 'MESH:D010243', 'target': 'NCBITaxon:6282', 'key': 'REDUCES'},
#    {'source': 'NCBITaxon:6282', 'target': 'MESH:D009855', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'ivermectin',
#    'disease': 'Onchocerciasis',
#    'drugbank': 'DB00602',
#    'drug_mesh': 'MESH:D007559',
#    'disease_mesh': 'MESH:D009855'},
#   'nodes': [{'id': 'MESH:D007559', 'name': 'ivermectin', 'label': 'Drug'},
#    {'id': 'InterPro:IPR015680',
#     'name': 'glutimate-gated chloride channels',
#     'label': 'Protein Family'},
#    {'id': 'CHEBI:17996', 'name': 'chloride ion', 'label': 'Compound'},
#    {'id': 'GO:0060081',
#     'name': 'membrane hyperpolarization',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D010243', 'name': 'Paralysis', 'label': 'Biological Process'},
#    {'id': 'NCBITaxon:6282', 'name': 'Onchocerca volvulus', 'label': 'Disease'},
#    {'id': 'MESH:D009855', 'name': 'Onchocerciasis', 'label': None}],
#   'links': [{'source': 'MESH:D007559',
#     'target': 'InterPro:IPR015680',
#     'key': 'ACTIVATES'},
#    {'source': 'InterPro:IPR015680',
#     'target': 'CHEBI:17996',
#     'key': 'INCREASES'},
#    {'source': 'CHEBI:17996', 'target': 'GO:0060081', 'key': 'PART_OF'},
#    {'source': 'GO:0060081', 'target': 'MESH:D010243', 'key': 'CAUSES'},
#    {'source': 'MESH:D010243', 'target': 'NCBITaxon:6282', 'key': 'REDUCES'},
#    {'source': 'NCBITaxon:6282', 'target': 'MESH:D009855', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'cobicistat',
#    'disease': 'HIV infection',
#    'drugbank': 'DB09065',
#    'drug_mesh': 'MESH:D000069547',
#    'disease_mesh': 'MESH:D015658'},
#   'nodes': [{'id': 'MESH:D000069547', 'name': 'cobicistat', 'label': 'Drug'},
#    {'id': 'UniProt:Q9HB55',
#     'name': 'cytochrome P450 3A (CYP3A) isoforms',
#     'label': 'Protein'},
#    {'id': 'MESH:D000069446', 'name': 'atazanavir', 'label': 'Compound'},
#    {'id': 'UniProt:P04585', 'name': 'Gag-Pol polyprotein', 'label': 'Protein'},
#    {'id': 'GO:0019068',
#     'name': 'Viral Assembly',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015658', 'name': 'HIV infection', 'label': 'Disease'}],
#   'links': [{'source': 'MESH:D000069547',
#     'target': 'UniProt:Q9HB55',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9HB55', 'target': 'MESH:D000069446', 'key': 'REDUCES'},
#    {'source': 'MESH:D000069446',
#     'target': 'UniProt:P04585',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:P04585', 'target': 'GO:0019068', 'key': 'INVOLVED_IN'},
#    {'source': 'GO:0019068', 'target': 'MESH:D015658', 'key': 'CAUSES'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'avelumab',
#    'disease': 'Merkel cell carcinoma',
#    'drugbank': 'DB11945',
#    'drug_mesh': 'MESH:C000609138',
#    'disease_mesh': 'MESH:D015266'},
#   'nodes': [{'id': 'MESH:C000609138', 'name': 'avelumab', 'label': 'Drug'},
#    {'id': 'UniProt:Q9NZQ7',
#     'name': 'Programmed cell death 1 ligand 1',
#     'label': 'Protein'},
#    {'id': 'GO:0036037',
#     'name': 'Cytotoxic T-Cell activity',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008283',
#     'name': 'Cell proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015266',
#     'name': 'Merkel cell carcinoma',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C000609138',
#     'target': 'UniProt:Q9NZQ7',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9NZQ7',
#     'target': 'GO:0036037',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0036037', 'target': 'GO:0008283', 'key': 'REDUCES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D015266', 'key': 'ELEVATED_IN'}]},
#  {'directed': True,
#   'multigraph': True,
#   'graph': {'drug': 'avelumab',
#    'disease': 'Merkel cell carcinoma',
#    'drugbank': 'DB11945',
#    'drug_mesh': 'MESH:C000609138',
#    'disease_mesh': 'MESH:D015266'},
#   'nodes': [{'id': 'MESH:C000609138', 'name': 'avelumab', 'label': 'Drug'},
#    {'id': 'UniProt:Q9NZQ7',
#     'name': 'Programmed cell death 1 ligand 1',
#     'label': 'Protein'},
#    {'id': 'GO:0036037',
#     'name': 'Cytotoxic T-Cell activity',
#     'label': 'Biological Process'},
#    {'id': 'GO:0008283',
#     'name': 'Cell proliferation',
#     'label': 'Biological Process'},
#    {'id': 'MESH:D015266',
#     'name': 'Merkel cell carcinoma',
#     'label': 'Disease'}],
#   'links': [{'source': 'MESH:C000609138',
#     'target': 'UniProt:Q9NZQ7',
#     'key': 'INHIBITS'},
#    {'source': 'UniProt:Q9NZQ7',
#     'target': 'GO:0036037',
#     'key': 'DOWN_REGULATES'},
#    {'source': 'GO:0036037', 'target': 'GO:0008283', 'key': 'REDUCES'},
#    {'source': 'GO:0008283', 'target': 'MESH:D015266', 'key': 'ELEVATED_IN'}]}]

# %%
# read a json as a dict
with open(osp.join(MAPPING_DIR, 'uniprot2ncbi.json')) as fl:
    uniprot2ncbi = json.load(fl)

with open(osp.join(MAPPING_DIR, 'drug_id_mapping.json')) as fl:
    drug_id_mapping = json.load(fl)

# %%
len(drug_id_mapping)
# Out:
# 63

# %% [markdown]
# Using these dictionaries, we'll map the nodes to the ontologies used in the KG:

# %%
def map_node(node):
    if node['label'] == 'Drug' and node['name'] in drug_id_mapping:
        return drug_id_mapping[node['name']]
    elif node['label'] == 'Protein' and node['id'] in uniprot2ncbi:
        return uniprot2ncbi[node['id']]
    else:
        return node['id']

# %% [markdown]
# Now, get a dictionary of the nodes and relations in each MOA:

# %%
validation_moas = defaultdict(lambda: {'nodes': None, 'relations': None})
not_mapped = set()
for path in data_json:
    # map the drug name to its pubchem ID
    if path['nodes'][0]['name'] not in drug_id_mapping:
        not_mapped.add(path['nodes'][0]['name'])
        continue
    start_node = drug_id_mapping[path['nodes'][0]['name']]
    for count, node in enumerate(path['nodes']):
        # if any node is BP,
        if node['label'] == 'Biological Process':
            end_node = path['nodes'][count]['id']
            # record those MOAs
            validation_moas[(start_node, end_node)]['nodes'] = [map_node(i) for i in path['nodes'][0:len(path['nodes'])-1]]
            validation_moas[(start_node, end_node)]['relations'] = [i['key'] for i in path['links'][0:len(path['links'])-1]]

len(validation_moas)
# Out:
# 53

# %% [markdown]
# DRUG - PROT - BP - PROT - BP

# %%
len(validation_moas.keys())
# Out:
# 53

# %% [markdown]
# Does it look how we want it to?
#
# - The keys are tuples comprising a pair of (drug, GO BP)
# - The values are dictionaries containing:
#     - nodes: a sequence of nodes in the MOA
#     - relations: a sequence of relation types in the MOA, which might not necessarily correspond to those in the KG:

# %%
dict(validation_moas)
# Out:
# {('pubchem.compound:5291',
#   'GO:0008283'): {'nodes': ['pubchem.compound:5291',
#    'ncbigene:5156',
#    'GO:0008283'], 'relations': ['INHIBITS', 'UP_REGULATES']},
#  ('pubchem.compound:1983',
#   'GO:0001659'): {'nodes': ['pubchem.compound:1983',
#    'REACT:R-HSA-2162123',
#    'UBERON:0000955',
#    'GO:0001659'], 'relations': ['INHIBITS', 'LOCALIZED_TO', 'REGULATES']},
#  ('pubchem.compound:2244',
#   'GO:0007596'): {'nodes': ['pubchem.compound:2244',
#    'ncbigene:5742',
#    'GO:0007596'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:156391',
#   'GO:0006954'): {'nodes': ['pubchem.compound:156391',
#    'ncbigene:5743',
#    'MESH:D011453',
#    'GO:0006954'], 'relations': ['INHIBITS', 'PRODUCES', 'PART_OF']},
#  ('pubchem.compound:5745',
#   'GO:0006954'): {'nodes': ['pubchem.compound:5745',
#    'ncbigene:2908',
#    'ncbigene:5742',
#    'MESH:D011453',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'DOWN_REGULATES',
#    'PRODUCES',
#    'PART_OF']},
#  ('pubchem.compound:5743',
#   'GO:0006954'): {'nodes': ['pubchem.compound:5743',
#    'ncbigene:2908',
#    'ncbigene:301',
#    'REACT:R-HSA-2162123',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'UP_REGULATES',
#    'DOWN_REGULATES',
#    'UP_REGULATES']},
#  ('pubchem.compound:4826',
#   'GO:0042311'): {'nodes': ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0042311',
#    'GO:0008217'], 'relations': ['ACTIVATES',
#    'INVOLVED_IN',
#    'ASSOCIATED_WITH']},
#  ('pubchem.compound:4826',
#   'GO:0008217'): {'nodes': ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0042311',
#    'GO:0008217'], 'relations': ['ACTIVATES',
#    'INVOLVED_IN',
#    'ASSOCIATED_WITH']},
#  ('pubchem.compound:2200',
#   'GO:0034776'): {'nodes': ['pubchem.compound:2200',
#    'ncbigene:3269',
#    'GO:0034776'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:149096',
#   'GO:0006260'): {'nodes': ['pubchem.compound:149096',
#    'ncbigene:7153',
#    'GO:0006260',
#    'NCBITaxon:562'], 'relations': ['INHIBITS', 'INVOLVED_IN', 'REQUIRED_FOR']},
#  ('pubchem.compound:444036',
#   'GO:0006954'): {'nodes': ['pubchem.compound:444036',
#    'ncbigene:2908',
#    'ncbigene:3586',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'UP_REGULATES',
#    'DOWN_REGULATES']},
#  ('pubchem.compound:3372',
#   'GO:0030252'): {'nodes': ['pubchem.compound:3372',
#    'ncbigene:1813',
#    'GO:0030252'], 'relations': ['INHIBITS', 'UP_REGULATES']},
#  ('pubchem.compound:6230',
#   'GO:0032275'): {'nodes': ['pubchem.compound:6230',
#    'ncbigene:5241',
#    'ncbigene:2796',
#    'GO:0032275'], 'relations': ['ACTIVATES',
#    'DOWN_REGULATES',
#    'DOWN_REGULATES']},
#  ('pubchem.compound:2564',
#   'GO:0034776'): {'nodes': ['pubchem.compound:2564',
#    'ncbigene:3269',
#    'GO:0034776'], 'relations': ['INHIBITS', 'UP_REGULATES']},
#  ('pubchem.compound:54678486',
#   'GO:0007596'): {'nodes': ['pubchem.compound:54678486',
#    'ncbigene:79001',
#    'MESH:D014812',
#    'GO:0007596'], 'relations': ['INHIBITS', 'PRODUCES', 'PART_OF']},
#  ('pubchem.compound:3957',
#   'GO:0034776'): {'nodes': ['pubchem.compound:3957',
#    'ncbigene:3269',
#    'GO:0034776'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:4636',
#   'GO:0042310'): {'nodes': ['pubchem.compound:4636',
#    'ncbigene:148',
#    'GO:0042310'], 'relations': ['ACTIVATES', 'UP_REGULATES']},
#  ('pubchem.compound:60835',
#   'GO:0051610'): {'nodes': ['pubchem.compound:60835',
#    'ncbigene:6532',
#    'GO:0051610'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:3162',
#   'GO:0034776'): {'nodes': ['pubchem.compound:3162',
#    'ncbigene:3269',
#    'GO:0034776'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:4201',
#   'GO:0042311'): {'nodes': ['pubchem.compound:4201',
#    'ncbigene:3758',
#    'GO:0042311',
#    'GO:0008217'], 'relations': ['ACTIVATES', 'INVOLVED_IN', 'REDUCES']},
#  ('pubchem.compound:4201',
#   'GO:0008217'): {'nodes': ['pubchem.compound:4201',
#    'ncbigene:3758',
#    'GO:0042311',
#    'GO:0008217'], 'relations': ['ACTIVATES', 'INVOLVED_IN', 'REDUCES']},
#  ('pubchem.compound:135398744',
#   'GO:0042311'): {'nodes': ['pubchem.compound:135398744',
#    'ncbigene:8654',
#    'MESH:D006152',
#    'GO:0042311'], 'relations': ['INHIBITS', 'REDUCES', 'PART_OF']},
#  ('pubchem.compound:9782',
#   'GO:0006954'): {'nodes': ['pubchem.compound:9782',
#    'ncbigene:2908',
#    'ncbigene:5321',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'DOWN_REGULATES',
#    'UP_REGULATES']},
#  ('pubchem.compound:5380',
#   'GO:0002553'): {'nodes': ['pubchem.compound:5380',
#    'GO:0002553'], 'relations': ['INHIBITS']},
#  ('pubchem.compound:6216',
#   'GO:0006954'): {'nodes': ['pubchem.compound:6216',
#    'ncbigene:2908',
#    'ncbigene:5321',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'DOWN_REGULATES',
#    'UP_REGULATES']},
#  ('pubchem.compound:3446',
#   'GO:0006936'): {'nodes': ['pubchem.compound:3446',
#    'ncbigene:781',
#    'GO:0006936'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:5755',
#   'GO:0006954'): {'nodes': ['pubchem.compound:5755',
#    'ncbigene:2908',
#    'ncbigene:301',
#    'ncbigene:5321',
#    'GO:0006954'], 'relations': ['ACTIVATES',
#    'UP_REGULATES',
#    'DOWN_REGULATES',
#    'INVOLVED_IN']},
#  ('pubchem.compound:443943',
#   'GO:0006954'): {'nodes': ['pubchem.compound:443943',
#    'GO:0006954'], 'relations': ['INHIBITS']},
#  ('pubchem.compound:16362',
#   'GO:0014046'): {'nodes': ['pubchem.compound:16362',
#    'ncbigene:1813',
#    'GO:0014046',
#    'HP:0100033'], 'relations': ['INHIBITS',
#    'ACTIVATED_BY',
#    'ASSOCIATED_WITH']},
#  ('pubchem.compound:13109',
#   'GO:0032275'): {'nodes': ['pubchem.compound:13109',
#    'ncbigene:5241',
#    'ncbigene:2796',
#    'GO:0032275'], 'relations': ['ACTIVATES',
#    'DOWN_REGULATES',
#    'DOWN_REGULATES']},
#  ('pubchem.compound:637568',
#   'GO:0006979'): {'nodes': ['pubchem.compound:637568',
#    'MESH:Q14145',
#    'ncbigene:4780',
#    'GO:0006979'], 'relations': ['INHIBITS',
#    'DOWN_REGULATES',
#    'DOWN_REGULATES']},
#  ('pubchem.compound:4976',
#   'GO:0023041'): {'nodes': ['pubchem.compound:4976',
#    'ncbigene:6530',
#    'MESH:D009638',
#    'GO:0023041'], 'relations': ['INHIBITS', 'REDUCES', 'PART_OF']},
#  ('pubchem.compound:5282136',
#   'GO:0001696'): {'nodes': ['pubchem.compound:5282136',
#    'ncbigene:3274',
#    'GO:0001696'], 'relations': ['INHIBITS', 'UP_REGULATES']},
#  ('pubchem.compound:114905',
#   'GO:0045823'): {'nodes': ['pubchem.compound:114905',
#    'ncbigene:153',
#    'GO:0045823'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:54385',
#   'GO:0034776'): {'nodes': ['pubchem.compound:54385',
#    'ncbigene:3269',
#    'GO:0034776'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:54676537',
#   'GO:0007596'): {'nodes': ['pubchem.compound:54676537',
#    'ncbigene:79001',
#    'MESH:D014812',
#    'GO:0007596'], 'relations': ['INHIBITS', 'PRODUCES', 'PART_OF']},
#  ('pubchem.compound:236702',
#   'GO:0019370'): {'nodes': ['pubchem.compound:236702',
#    'ncbigene:2908',
#    'ncbigene:301',
#    'ncbigene:5321',
#    'GO:0019370'], 'relations': ['ACTIVATES',
#    'UP_REGULATES',
#    'DOWN_REGULATES',
#    'UP_REGULATES']},
#  ('pubchem.compound:4170',
#   'GO:0055078'): {'nodes': ['pubchem.compound:4170',
#    'ncbigene:6559',
#    'GO:0055078'], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:9833444',
#   'GO:0032782'): {'nodes': ['pubchem.compound:9833444',
#    'GO:0032782'], 'relations': ['ACTIVATES']},
#  ('pubchem.compound:55191',
#   'GO:0050795'): {'nodes': ['pubchem.compound:55191',
#    'ncbigene:3350',
#    'GO:0050795'], 'relations': ['ACTIVATES', 'INVOLVED_IN']},
#  ('pubchem.compound:33741',
#   'GO:0019233'): {'nodes': ['pubchem.compound:33741',
#    'ncbigene:4988',
#    'GO:0019233'], 'relations': ['ACTIVATES', 'DOWN_REGULATES']},
#  ('pubchem.compound:5576',
#   'GO:0007268 '): {'nodes': ['pubchem.compound:5576',
#    'ncbigene:8913',
#    'GO:0007268 '], 'relations': ['INHIBITS', 'INVOLVED_IN']},
#  ('pubchem.compound:24872560',
#   'GO:0006351'): {'nodes': ['pubchem.compound:24872560',
#    'ncbigene:367',
#    'GO:0006351',
#    'GO:0008283'], 'relations': ['INHIBITS', 'UP_REGULATES', 'REQUIRED_FOR']},
#  ('pubchem.compound:24872560',
#   'GO:0008283'): {'nodes': ['pubchem.compound:24872560',
#    'ncbigene:367',
#    'GO:0006351',
#    'GO:0008283'], 'relations': ['INHIBITS', 'UP_REGULATES', 'REQUIRED_FOR']},
#  ('pubchem.compound:2145',
#   'GO:0008283'): {'nodes': ['pubchem.compound:2145',
#    'ncbigene:1588',
#    'MESH:D004967',
#    'GO:0008283'], 'relations': ['INHIBITS', 'PRODUCES', 'UP_REGULATES']},
#  ('pubchem.compound:204',
#   'GO:0042060'): {'nodes': ['pubchem.compound:204',
#    'GO:0042060'], 'relations': ['ACTIVATES']},
#  ('pubchem.compound:5339',
#   'GO:0019370'): {'nodes': ['pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0019370',
#    'GO:0006954'], 'relations': ['INHIBITS', 'UP_REGULATES', 'PART_OF']},
#  ('pubchem.compound:5339',
#   'GO:0006954'): {'nodes': ['pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0019370',
#    'GO:0006954'], 'relations': ['INHIBITS', 'UP_REGULATES', 'PART_OF']},
#  ('pubchem.compound:6421',
#   'GO:0070265'): {'nodes': ['pubchem.compound:6421',
#    'GO:0070265'], 'relations': ['ACTIVATES']},
#  ('pubchem.compound:3487',
#   'GO:1904862'): {'nodes': ['pubchem.compound:3487',
#    'ncbigene:2554',
#    'GO:1904862'], 'relations': ['ACTIVATES', 'INVOLVED_IN']},
#  ('pubchem.compound:16197727',
#   'GO:0042438'): {'nodes': ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0042438',
#    'MESH:C041877',
#    'GO:0009650',
#    'CHEBI:26523',
#    'MESH:C028025'], 'relations': ['ACTIVATES',
#    'INVOLVED_IN',
#    'UP_REGULATES',
#    'PART_OF',
#    'REDUCES',
#    'INCREASED_BY']},
#  ('pubchem.compound:16197727',
#   'GO:0009650'): {'nodes': ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0042438',
#    'MESH:C041877',
#    'GO:0009650',
#    'CHEBI:26523',
#    'MESH:C028025'], 'relations': ['ACTIVATES',
#    'INVOLVED_IN',
#    'UP_REGULATES',
#    'PART_OF',
#    'REDUCES',
#    'INCREASED_BY']},
#  ('pubchem.compound:25151504',
#   'GO:0019068'): {'nodes': ['pubchem.compound:25151504',
#    'ncbigene:64816',
#    'MESH:D000069446',
#    'UniProt:P04585',
#    'GO:0019068'], 'relations': ['INHIBITS',
#    'REDUCES',
#    'INHIBITS',
#    'INVOLVED_IN']}}

# %% [markdown]
# Do they correspond with the pairs that Yojana previously found?

# %%
connected_pairs = pd.read_csv(osp.join(KG_DIR, 'test.tsv'), sep='\t', header=0)
cpairs = [(row['source'], row['target']) for i, row in connected_pairs.iterrows()]
len(cpairs)
# Out:
# 48

# %%
len(set(validation_moas.keys()) & set(cpairs))
# Out:
# 47

# %% [markdown]
# No they don't...

# %%
set(cpairs) - set(validation_moas.keys())
# Out:
# {('pubchem.compound:5745', 'GO:0050900')}

# %%
paths.loc[paths['n1'] == "cortisone acetate"]
# Out:
#                    n1                    e1                       n2  \
# 14  cortisone acetate  INCREASES_EXPRESSION             lipocortin-1
# 15  cortisone acetate  DECREASES_EXPRESSION                COX Genes
# 16  cortisone acetate  INCREASES_EXPRESSION             lipocortin-1
# 17  cortisone acetate             ACTIVATES  Glucocorticoid receptor
# 18  cortisone acetate             ACTIVATES  Glucocorticoid receptor
#
#                 e2                       n3              e3  \
# 14  DOWN_REGULATES  Prostaglandin Synthesis     INVOLVED_IN
# 15        PRODUCES           Prostaglandins         PART_OF
# 16  DOWN_REGULATES     Immune Cell Funciton    UP_REGULATES
# 17    UP_REGULATES               Annexin A1  DOWN_REGULATES
# 18  DOWN_REGULATES                COX genes        PRODUCES
#
#                          n4            e4            n5      e5         n6  \
# 14             Inflammation        CAUSES     Keratitis     NaN        NaN
# 15             Inflammation        CAUSES     Keratitis     NaN        NaN
# 16             Inflammation        CAUSES     Keratitis     NaN        NaN
# 17  Prostaglandin Synthesis  UP_REGULATES  Inflammation  CAUSES  Keratitis
# 18           Prostaglandins       PART_OF  Inflammation  CAUSES  Keratitis
#
#      e6   n7   e7   n8
# 14  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN

# %% [markdown]
# Since it's just one, let's move on:

# %% [markdown]
# Now, we'll get lists from the output file of MARS:

# %%
OUTPUT_DIR = '../data/output'

# %%
file_path = osp.join(OUTPUT_DIR, 'paths_CtBP')

with open(file_path, 'r') as file:

    lines = file.readlines()

# %%
breakpoints = [i for i, line in enumerate(lines) if line.startswith("#####################")]

# %%
chunks = []
startpoint = 0
for brk in breakpoints:
    chunk = lines[startpoint:brk]
    if chunk[1].strip() == 'Reward:1':
        chunks.append(chunk)
    startpoint = brk + 1

# %%
pred_paths = dict()

for chunk in chunks:
    srt = 0
    current_pair = tuple(chunk[0].split())
    pred_paths[current_pair] = {'nodes': [], 'relations': []}
    chunk = chunk[2::]
    breakpoints = [i for i, line in enumerate(chunk) if line.startswith("___")]
    for brk in breakpoints:
        entry = chunk[srt:brk]
        if entry[2].strip() == '1':
            pred_paths[current_pair]['nodes'].append(entry[0].strip().split('\t'))
            pred_paths[current_pair]['relations'].append(entry[1].strip().split('\t'))
        srt = brk + 1

# %%
pred_paths.keys()
# Out:
# dict_keys([('pubchem.compound:2265', 'GO:0002376'), ('pubchem.compound:26987', 'GO:0044281'), ('pubchem.compound:5282379', 'GO:0032880'), ('pubchem.compound:31307', 'GO:0022607'), ('pubchem.compound:126941', 'GO:0022618'), ('pubchem.compound:24872560', 'GO:0006351'), ('pubchem.compound:3162', 'GO:0034776'), ('pubchem.compound:5095', 'GO:0006629'), ('pubchem.compound:16197727', 'GO:0042438'), ('pubchem.compound:54678486', 'GO:0007596'), ('pubchem.compound:107807', 'GO:0050877'), ('pubchem.compound:5330286', 'GO:0002376'), ('pubchem.compound:31703', 'GO:0030154'), ('pubchem.compound:10631', 'GO:0030705'), ('pubchem.compound:44093', 'GO:0044281'), ('pubchem.compound:6167', 'GO:0048856'), ('pubchem.compound:4197', 'GO:0006629'), ('pubchem.compound:5503', 'GO:0044281'), ('pubchem.compound:31703', 'GO:0050877'), ('pubchem.compound:31703', 'GO:0006259'), ('pubchem.compound:3676', 'GO:0044281'), ('pubchem.compound:16197727', 'GO:0009650'), ('pubchem.compound:53232', 'GO:0006629'), ('pubchem.compound:2733526', 'GO:0048856'), ('pubchem.compound:457193', 'GO:0043085'), ('pubchem.compound:4011', 'GO:0050790'), ('pubchem.compound:2200', 'GO:0034776'), ('pubchem.compound:37542', 'GO:0006629'), ('pubchem.compound:457193', 'GO:0042592'), ('pubchem.compound:2812', 'GO:0002376'), ('pubchem.compound:2265', 'GO:0007017'), ('pubchem.compound:60854', 'GO:0005975'), ('pubchem.compound:4158', 'GO:0055085'), ('pubchem.compound:149096', 'GO:0006260'), ('pubchem.compound:5280360', 'GO:0007267'), ('pubchem.compound:3488', 'GO:0007165'), ('pubchem.compound:6215', 'GO:0048646'), ('pubchem.compound:456201', 'GO:0070989'), ('pubchem.compound:3652', 'GO:0048856'), ('pubchem.compound:2724385', 'GO:0030154'), ('pubchem.compound:447043', 'GO:0007010'), ('pubchem.compound:2812', 'GO:0007010'), ('pubchem.compound:3715', 'GO:0042592'), ('pubchem.compound:3826', 'GO:0030154'), ('pubchem.compound:9829523', 'GO:0008283'), ('pubchem.compound:444795', 'GO:0048856'), ('pubchem.compound:9444', 'GO:0006259'), ('pubchem.compound:54385', 'GO:0034776'), ('pubchem.compound:32798', 'GO:0007165'), ('pubchem.compound:3547', 'GO:0022607'), ('pubchem.compound:4828', 'GO:0048646'), ('pubchem.compound:2082', 'GO:0050877'), ('pubchem.compound:4170', 'GO:0055078'), ('pubchem.compound:4916', 'GO:0007017'), ('pubchem.compound:5790', 'GO:0006913'), ('pubchem.compound:10607', 'GO:0044281'), ('pubchem.compound:3019', 'GO:0044281'), ('pubchem.compound:5339', 'GO:0006954'), ('pubchem.compound:126941', 'GO:0009790'), ('pubchem.compound:5330286', 'GO:0006259'), ('pubchem.compound:5564', 'GO:0061024'), ('pubchem.compound:2797', 'GO:0044281'), ('pubchem.compound:1548887', 'GO:0070989'), ('pubchem.compound:444795', 'GO:0008283'), ('pubchem.compound:44093', 'GO:0048646'), ('pubchem.compound:4011', 'GO:0043085'), ('pubchem.compound:4828', 'GO:0007017'), ('pubchem.compound:32798', 'GO:0006805'), ('pubchem.compound:4636', 'GO:0042310'), ('pubchem.compound:4011', 'GO:0032880'), ('pubchem.compound:60854', 'GO:0016192'), ('pubchem.compound:5405', 'GO:0006913'), ('pubchem.compound:5339', 'GO:0019370'), ('pubchem.compound:8378', 'GO:0050877'), ('pubchem.compound:10607', 'GO:0007165'), ('pubchem.compound:4168', 'GO:0022607'), ('pubchem.compound:4828', 'GO:0002376'), ('pubchem.compound:44462760', 'GO:0048856'), ('pubchem.compound:5073', 'GO:0008219'), ('pubchem.compound:11625818', 'GO:0048646'), ('pubchem.compound:5790', 'GO:0032880'), ('pubchem.compound:2724385', 'GO:0016192'), ('pubchem.compound:4828', 'GO:0032880'), ('pubchem.compound:9829523', 'GO:0048646'), ('pubchem.compound:4201', 'GO:0042311'), ('pubchem.compound:3476', 'GO:0044281'), ('pubchem.compound:4011', 'GO:0022607'), ('pubchem.compound:24826799', 'GO:0055085'), ('pubchem.compound:2797', 'GO:0006805'), ('pubchem.compound:44462760', 'GO:0002376'), ('pubchem.compound:3385', 'GO:0007017'), ('pubchem.compound:3117', 'GO:0055085'), ('pubchem.compound:44462760', 'GO:0050877'), ('pubchem.compound:44462760', 'GO:0022607'), ('pubchem.compound:9931954', ...

# %% [markdown]
# I want to see what the predicted paths look like:

# %%
patterns_traversed = []

for val in pred_paths.values():
    patterns_traversed.extend(val['relations'])

# %%
patterns_traversed = [str(i) for i in patterns_traversed]
Counter(patterns_traversed)
# Out:
# Counter({"['CtBP', '_CtBP', 'CtBP']": 2728,
#          "['NO_OP', 'CdG', 'GpBP']": 21,
#          "['CdG', 'GpBP', 'NO_OP']": 21,
#          "['CdG', 'NO_OP', 'GpBP']": 13,
#          "['NO_OP', 'CuG', 'GpBP']": 9,
#          "['CuG', 'GpBP', 'NO_OP']": 9,
#          "['CuG', 'NO_OP', 'GpBP']": 7,
#          "['CtBP', '_GpBP', 'GpBP']": 2,
#          "['CdG', '_CdG', 'CtBP']": 1})

# %% [markdown]
# This `['CtBP', '_CtBP', 'CtBP']` is very prominent. What happens if we get rid of any pairs predicted with this?

# %%
file_path = osp.join(OUTPUT_DIR, 'paths_CtBP')

with open(file_path, 'r') as file:

    lines = file.readlines()

# %%
breakpoints = [i for i, line in enumerate(lines) if line.startswith("#####################")]

# %%
chunks = []
startpoint = 0
for brk in breakpoints:
    chunk = lines[startpoint:brk]
    if chunk[1].strip() == 'Reward:1':
        chunks.append(chunk)
    startpoint = brk + 1

# %%
pred_paths = dict()

for chunk in chunks:
    srt = 0
    current_pair = tuple(chunk[0].split())
    chunk = chunk[2::]
    breakpoints = [i for i, line in enumerate(chunk) if line.startswith("___")]
    for brk in breakpoints:
        entry = chunk[srt:brk]
        if entry[2].strip() == '1' and entry[1].strip().split('\t') != ['CtBP', '_CtBP', 'CtBP']:
            if current_pair not in pred_paths:
                pred_paths[current_pair] = {'nodes': [], 'relations': []}
            pred_paths[current_pair]['nodes'].append(entry[0].strip().split('\t'))
            pred_paths[current_pair]['relations'].append(entry[1].strip().split('\t'))
        srt = brk + 1

# %%
len(pred_paths)
# Out:
# 32

# %%
found_keys = set(pred_paths.keys()) & validation_moas.keys()
len(found_keys)
# Out:
# 29

# %%
pred_paths
# Out:
# {('pubchem.compound:16197727',
#   'GO:0042438'): {'nodes': [['pubchem.compound:16197727',
#     'pubchem.compound:16197727',
#     'ncbigene:4157',
#     'GO:0042438'],
#    ['pubchem.compound:16197727', 'ncbigene:4157', 'GO:0042438', 'GO:0042438'],
#    ['pubchem.compound:16197727',
#     'ncbigene:4157',
#     'ncbigene:4157',
#     'GO:0042438']], 'relations': [['NO_OP', 'CuG', 'GpBP'],
#    ['CuG', 'GpBP', 'NO_OP'],
#    ['CuG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:54678486',
#   'GO:0007596'): {'nodes': [['pubchem.compound:54678486',
#     'pubchem.compound:54678486',
#     'ncbigene:79001',
#     'GO:0007596'],
#    ['pubchem.compound:54678486', 'ncbigene:79001', 'GO:0007596', 'GO:0007596'],
#    ['pubchem.compound:54678486',
#     'ncbigene:79001',
#     'ncbigene:79001',
#     'GO:0007596']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:16197727',
#   'GO:0009650'): {'nodes': [['pubchem.compound:16197727',
#     'pubchem.compound:16197727',
#     'ncbigene:4157',
#     'GO:0009650'],
#    ['pubchem.compound:16197727', 'ncbigene:4157', 'GO:0009650', 'GO:0009650'],
#    ['pubchem.compound:16197727',
#     'ncbigene:4157',
#     'ncbigene:4157',
#     'GO:0009650']], 'relations': [['NO_OP', 'CuG', 'GpBP'],
#    ['CuG', 'GpBP', 'NO_OP'],
#    ['CuG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:149096',
#   'GO:0006260'): {'nodes': [['pubchem.compound:149096',
#     'ncbigene:7153',
#     'GO:0006260',
#     'GO:0006260'],
#    ['pubchem.compound:149096',
#     'pubchem.compound:149096',
#     'ncbigene:7153',
#     'GO:0006260']], 'relations': [['CdG', 'GpBP', 'NO_OP'],
#    ['NO_OP', 'CdG', 'GpBP']]},
#  ('pubchem.compound:4170',
#   'GO:0055078'): {'nodes': [['pubchem.compound:4170',
#     'pubchem.compound:4170',
#     'ncbigene:6559',
#     'GO:0055078'],
#    ['pubchem.compound:4170', 'ncbigene:6559', 'GO:0055078', 'GO:0055078'],
#    ['pubchem.compound:4170',
#     'ncbigene:6559',
#     'ncbigene:6559',
#     'GO:0055078']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:5339',
#   'GO:0006954'): {'nodes': [['pubchem.compound:5339',
#     'pubchem.compound:5339',
#     'ncbigene:240',
#     'GO:0006954'],
#    ['pubchem.compound:5339', 'ncbigene:240', 'GO:0006954', 'GO:0006954'],
#    ['pubchem.compound:5339',
#     'ncbigene:240',
#     'ncbigene:240',
#     'GO:0006954']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:5339',
#   'GO:0019370'): {'nodes': [['pubchem.compound:5339',
#     'pubchem.compound:5339',
#     'ncbigene:240',
#     'GO:0019370'],
#    ['pubchem.compound:5339', 'ncbigene:240', 'GO:0019370', 'GO:0019370'],
#    ['pubchem.compound:5339',
#     'ncbigene:240',
#     'ncbigene:240',
#     'GO:0019370']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:54676537',
#   'GO:0007596'): {'nodes': [['pubchem.compound:54676537',
#     'pubchem.compound:54676537',
#     'ncbigene:79001',
#     'GO:0007596'],
#    ['pubchem.compound:54676537', 'ncbigene:79001', 'GO:0007596', 'GO:0007596'],
#    ['pubchem.compound:54676537',
#     'ncbigene:79001',
#     'ncbigene:79001',
#     'GO:0007596']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:5282136',
#   'GO:0001696'): {'nodes': [['pubchem.compound:5282136',
#     'pubchem.compound:5282136',
#     'ncbigene:3274',
#     'GO:0001696'],
#    ['pubchem.compound:5282136', 'ncbigene:3274', 'GO:0001696', 'GO:0001696'],
#    ['pubchem.compound:5282136',
#     'ncbigene:3274',
#     'ncbigene:3274',
#     'GO:0001696']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:3446',
#   'GO:0006936'): {'nodes': [['pubchem.compound:3446',
#     'pubchem.compound:3446',
#     'ncbigene:781',
#     'GO:0006936'],
#    ['pubchem.compound:3446',
#     'ncbigene:781',
#     'GO:0006936',
#     'GO:0006936']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP']]},
#  ('pubchem.compound:4201',
#   'GO:0008217'): {'nodes': [['pubchem.compound:4201',
#     'ncbigene:3758',
#     'GO:0008217',
#     'GO:0008217'],
#    ['pubchem.compound:4201',
#     'pubchem.compound:4201',
#     'ncbigene:3758',
#     'GO:0008217']], 'relations': [['CuG', 'GpBP', 'NO_OP'],
#    ['NO_OP', 'CuG', 'GpBP']]},
#  ('pubchem.compound:55191',
#   'GO:0050795'): {'nodes': [['pubchem.compound:55191',
#     'ncbigene:3350',
#     'GO:0050795',
#     'GO:0050795'],
#    ['pubchem.compound:55191',
#     'pubchem.compound:55191',
#     'ncbigene:3350',
#     'GO:0050795']], 'relations': [['CuG', 'GpBP', 'NO_OP'],
#    ['NO_OP', 'CuG', 'GpBP']]},
#  ('pubchem.compound:135398744',
#   'GO:0042311'): {'nodes': [['pubchem.compound:135398744',
#     'pubchem.compound:135398744',
#     'ncbigene:8654',
#     'GO:0042311'],
#    ['pubchem.compound:135398744', 'ncbigene:8654', 'GO:0042311', 'GO:0042311'],
#    ['pubchem.compound:135398744',
#     'ncbigene:8654',
#     'ncbigene:8654',
#     'GO:0042311']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:25151504',
#   'GO:0019068'): {'nodes': [['pubchem.compound:25151504',
#     'pubchem.compound:25151504',
#     'ncbigene:64816',
#     'GO:0019068'],
#    ['pubchem.compound:25151504', 'ncbigene:64816', 'GO:0019068', 'GO:0019068'],
#    ['pubchem.compound:25151504',
#     'ncbigene:64816',
#     'ncbigene:64816',
#     'GO:0019068']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:4826',
#   'GO:0042311'): {'nodes': [['pubchem.compound:4826',
#     'pubchem.compound:4826',
#     'ncbigene:3778',
#     'GO:0042311'],
#    ['pubchem.compound:4826', 'ncbigene:3778', 'GO:0042311', 'GO:0042311'],
#    ['pubchem.compound:4826',
#     'ncbigene:3778',
#     'ncbigene:3778',
#     'GO:0042311']], 'relations': [['NO_OP', 'CuG', 'GpBP'],
#    ['CuG', 'GpBP', 'NO_OP'],
#    ['CuG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:4976',
#   'GO:0023041'): {'nodes': [['pubchem.compound:4976',
#     'pubchem.compound:4976',
#     'ncbigene:6530',
#     'GO:0023041'],
#    ['pubchem.compound:4976', 'ncbigene:6530', 'GO:0023041', 'GO:0023041'],
#    ['pubchem.compound:4976',
#     'ncbigene:6530',
#     'ncbigene:6530',
#     'GO:0023041']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:4826',
#   'GO:0008217'): {'nodes': [['pubchem.compound:4826',
#     'pubchem.compound:4826',
#     'ncbigene:3778',
#     'GO:0008217'],
#    ['pubchem.compound:4826', 'ncbigene:3778', 'GO:0008217', 'GO:0008217'],
#    ['pubchem.compound:4826',
#     'ncbigene:3778',
#     'ncbigene:3778',
#     'GO:0008217']], 'relations': [['NO_OP', 'CuG', 'GpBP'],
#    ['CuG', 'GpBP', 'NO_OP'],
#    ['CuG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:5576',
#   'GO:0007268'): {'nodes': [['pubchem.compound:5576',
#     'pubchem.compound:5576',
#     'ncbigene:8913',
#     'GO:0007268'],
#    ['pubchem.compound:5576', 'ncbigene:8913', 'GO:0007268 ', 'GO:0007268'],
#    ['pubchem.compound:5576',
#     'ncbigene:8913',
#     'ncbigene:8913',
#     'GO:0007268']], 'relations': [['NO_OP', 'CdG', 'GpBP'],
#    ['CdG', 'GpBP', 'NO_OP'],
#    ['CdG', 'NO_OP', 'GpBP']]},
#  ('pubchem.compound:2145',
#   'GO:0048646'): {'nodes': [['pubchem.compound:2145',
#     'ncbigene:1588',
#     'pubchem.compound:60198',
#     'GO:0048646']], 'relations': [['CdG', '_CdG', 'CtBP']]},
#  ('pubchem.compound:3168',
#   'GO:0055085'): {'nodes': [['pubchem.compound:3168',
#     'ncbigene:1813',
#     'pubchem.compound:4078',
#     'GO:0055085'],
#    ['pubchem.compound:3168',
#     'ncbigene:148',
#     'pubchem.compound:441074',
#     'GO:0055085']], 'relations': [['CdG', '_CdG', 'CtBP'],
#    ['CdG', '_CdG', 'CtBP']]},
#  ('pubchem.compound:2162',
#   'GO:0050877'): {'nodes': [['pubchem.compound:2162',
#     'GO:0007165',
#     'ncbigene:170572',
#     'GO:0050877'],
#    ['pubchem.compound:2162',
#     'GO:0007165',
#     'ncbigene:285242',
#     'GO:0050877']], 'relations': [['CtBP', '_GpBP', 'GpBP'],
#    ['CtBP', '_GpBP', 'GpBP']]}}

# %% [markdown]
# Yay, now let's write code to see if we can compare the paths found by the method.
#
# First, we'll see how many of the DrugMechDB pairs were found:

# %%
found_keys = set(pred_paths.keys()) & validation_moas.keys()
len(found_keys)
# Out:
# 17

# %%
found_keys
# Out:
# {('pubchem.compound:135398744', 'GO:0042311'),
#  ('pubchem.compound:149096', 'GO:0006260'),
#  ('pubchem.compound:16197727', 'GO:0009650'),
#  ('pubchem.compound:16197727', 'GO:0042438'),
#  ('pubchem.compound:25151504', 'GO:0019068'),
#  ('pubchem.compound:3446', 'GO:0006936'),
#  ('pubchem.compound:4170', 'GO:0055078'),
#  ('pubchem.compound:4201', 'GO:0008217'),
#  ('pubchem.compound:4826', 'GO:0008217'),
#  ('pubchem.compound:4826', 'GO:0042311'),
#  ('pubchem.compound:4976', 'GO:0023041'),
#  ('pubchem.compound:5282136', 'GO:0001696'),
#  ('pubchem.compound:5339', 'GO:0006954'),
#  ('pubchem.compound:5339', 'GO:0019370'),
#  ('pubchem.compound:54676537', 'GO:0007596'),
#  ('pubchem.compound:54678486', 'GO:0007596'),
#  ('pubchem.compound:55191', 'GO:0050795')}

# %%
print(f"{len(found_keys) / len(validation_moas) * 100}% of the DrugMechDB pairs were predicted correctly.")
# Out:
# 32.075471698113205% of the DrugMechDB pairs were predicted correctly.

# %% [markdown]
# From these, let's compare whether the correct paths were found:

# %%
real_moas = {key: val['nodes'] for key, val in validation_moas.items() if key in found_keys}
real_moas
# Out:
# {('pubchem.compound:4826', 'GO:0042311'): ['pubchem.compound:4826',
#   'ncbigene:3778',
#   'GO:0042311',
#   'GO:0008217'],
#  ('pubchem.compound:4826', 'GO:0008217'): ['pubchem.compound:4826',
#   'ncbigene:3778',
#   'GO:0042311',
#   'GO:0008217'],
#  ('pubchem.compound:149096', 'GO:0006260'): ['pubchem.compound:149096',
#   'ncbigene:7153',
#   'GO:0006260',
#   'NCBITaxon:562'],
#  ('pubchem.compound:54678486', 'GO:0007596'): ['pubchem.compound:54678486',
#   'ncbigene:79001',
#   'MESH:D014812',
#   'GO:0007596'],
#  ('pubchem.compound:4201', 'GO:0008217'): ['pubchem.compound:4201',
#   'ncbigene:3758',
#   'GO:0042311',
#   'GO:0008217'],
#  ('pubchem.compound:135398744', 'GO:0042311'): ['pubchem.compound:135398744',
#   'ncbigene:8654',
#   'MESH:D006152',
#   'GO:0042311'],
#  ('pubchem.compound:3446', 'GO:0006936'): ['pubchem.compound:3446',
#   'ncbigene:781',
#   'GO:0006936'],
#  ('pubchem.compound:4976', 'GO:0023041'): ['pubchem.compound:4976',
#   'ncbigene:6530',
#   'MESH:D009638',
#   'GO:0023041'],
#  ('pubchem.compound:5282136', 'GO:0001696'): ['pubchem.compound:5282136',
#   'ncbigene:3274',
#   'GO:0001696'],
#  ('pubchem.compound:54676537', 'GO:0007596'): ['pubchem.compound:54676537',
#   'ncbigene:79001',
#   'MESH:D014812',
#   'GO:0007596'],
#  ('pubchem.compound:4170', 'GO:0055078'): ['pubchem.compound:4170',
#   'ncbigene:6559',
#   'GO:0055078'],
#  ('pubchem.compound:55191', 'GO:0050795'): ['pubchem.compound:55191',
#   'ncbigene:3350',
#   'GO:0050795'],
#  ('pubchem.compound:5339', 'GO:0019370'): ['pubchem.compound:5339',
#   'ncbigene:240',
#   'GO:0019370',
#   'GO:0006954'],
#  ('pubchem.compound:5339', 'GO:0006954'): ['pubchem.compound:5339',
#   'ncbigene:240',
#   'GO:0019370',
#   'GO:0006954'],
#  ('pubchem.compound:16197727', 'GO:0042438'): ['pubchem.compound:16197727',
#   'ncbigene:4157',
#   'GO:0042438',
#   'MESH:C041877',
#   'GO:0009650',
#   'CHEBI:26523',
#   'MESH:C028025'],
#  ('pubchem.compound:16197727', 'GO:0009650'): ['pubchem.compound:16197727',
#   'ncbigene:4157',
#   'GO:0042438',
#   'MESH:C041877',
#   'GO:0009650',
#   'CHEBI:26523',
#   'MESH:C028025'],
#  ('pubchem.compound:25151504', 'GO:0019068'): ['pubchem.compound:25151504',
#   'ncbigene:64816',
#   'MESH:D000069446',
#   'UniProt:P04585',
#   'GO:0019068']}

# %%
for key, val in real_moas.items():
    if len(val) > 3:
        print(key, val)
# Out:
# ('pubchem.compound:4826', 'GO:0042311') ['pubchem.compound:4826', 'ncbigene:3778', 'GO:0042311', 'GO:0008217']
# ('pubchem.compound:4826', 'GO:0008217') ['pubchem.compound:4826', 'ncbigene:3778', 'GO:0042311', 'GO:0008217']
# ('pubchem.compound:149096', 'GO:0006260') ['pubchem.compound:149096', 'ncbigene:7153', 'GO:0006260', 'NCBITaxon:562']
# ('pubchem.compound:54678486', 'GO:0007596') ['pubchem.compound:54678486', 'ncbigene:79001', 'MESH:D014812', 'GO:0007596']
# ('pubchem.compound:4201', 'GO:0008217') ['pubchem.compound:4201', 'ncbigene:3758', 'GO:0042311', 'GO:0008217']
# ('pubchem.compound:135398744', 'GO:0042311') ['pubchem.compound:135398744', 'ncbigene:8654', 'MESH:D006152', 'GO:0042311']
# ('pubchem.compound:4976', 'GO:0023041') ['pubchem.compound:4976', 'ncbigene:6530', 'MESH:D009638', 'GO:0023041']
# ('pubchem.compound:54676537', 'GO:0007596') ['pubchem.compound:54676537', 'ncbigene:79001', 'MESH:D014812', 'GO:0007596']
# ('pubchem.compound:5339', 'GO:0019370') ['pubchem.compound:5339', 'ncbigene:240', 'GO:0019370', 'GO:0006954']
# ('pubchem.compound:5339', 'GO:0006954') ['pubchem.compound:5339', 'ncbigene:240', 'GO:0019370', 'GO:0006954']
# ('pubchem.compound:16197727', 'GO:0042438') ['pubchem.compound:16197727', 'ncbigene:4157', 'GO:0042438', 'MESH:C041877', 'GO:0009650', 'CHEBI:26523', 'MESH:C028025']
# ('pubchem.compound:16197727', 'GO:0009650') ['pubchem.compound:16197727', 'ncbigene:4157', 'GO:0042438', 'MESH:C041877', 'GO:0009650', 'CHEBI:26523', 'MESH:C028025']
# ('pubchem.compound:25151504', 'GO:0019068') ['pubchem.compound:25151504', 'ncbigene:64816', 'MESH:D000069446', 'UniProt:P04585', 'GO:0019068']

# %%
pred_moas = {key: val['nodes'] for key, val in pred_paths.items() if key in found_keys}
pred_moas
# Out:
# {('pubchem.compound:16197727',
#   'GO:0042438'): [['pubchem.compound:16197727',
#    'pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0042438'], ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0042438',
#    'GO:0042438'], ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'ncbigene:4157',
#    'GO:0042438']],
#  ('pubchem.compound:54678486',
#   'GO:0007596'): [['pubchem.compound:54678486',
#    'pubchem.compound:54678486',
#    'ncbigene:79001',
#    'GO:0007596'], ['pubchem.compound:54678486',
#    'ncbigene:79001',
#    'GO:0007596',
#    'GO:0007596'], ['pubchem.compound:54678486',
#    'ncbigene:79001',
#    'ncbigene:79001',
#    'GO:0007596']],
#  ('pubchem.compound:16197727',
#   'GO:0009650'): [['pubchem.compound:16197727',
#    'pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0009650'], ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'GO:0009650',
#    'GO:0009650'], ['pubchem.compound:16197727',
#    'ncbigene:4157',
#    'ncbigene:4157',
#    'GO:0009650']],
#  ('pubchem.compound:149096',
#   'GO:0006260'): [['pubchem.compound:149096',
#    'ncbigene:7153',
#    'GO:0006260',
#    'GO:0006260'], ['pubchem.compound:149096',
#    'pubchem.compound:149096',
#    'ncbigene:7153',
#    'GO:0006260']],
#  ('pubchem.compound:4170',
#   'GO:0055078'): [['pubchem.compound:4170',
#    'pubchem.compound:4170',
#    'ncbigene:6559',
#    'GO:0055078'], ['pubchem.compound:4170',
#    'ncbigene:6559',
#    'GO:0055078',
#    'GO:0055078'], ['pubchem.compound:4170',
#    'ncbigene:6559',
#    'ncbigene:6559',
#    'GO:0055078']],
#  ('pubchem.compound:5339',
#   'GO:0006954'): [['pubchem.compound:5339',
#    'pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0006954'], ['pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0006954',
#    'GO:0006954'], ['pubchem.compound:5339',
#    'ncbigene:240',
#    'ncbigene:240',
#    'GO:0006954']],
#  ('pubchem.compound:5339',
#   'GO:0019370'): [['pubchem.compound:5339',
#    'pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0019370'], ['pubchem.compound:5339',
#    'ncbigene:240',
#    'GO:0019370',
#    'GO:0019370'], ['pubchem.compound:5339',
#    'ncbigene:240',
#    'ncbigene:240',
#    'GO:0019370']],
#  ('pubchem.compound:54676537',
#   'GO:0007596'): [['pubchem.compound:54676537',
#    'pubchem.compound:54676537',
#    'ncbigene:79001',
#    'GO:0007596'], ['pubchem.compound:54676537',
#    'ncbigene:79001',
#    'GO:0007596',
#    'GO:0007596'], ['pubchem.compound:54676537',
#    'ncbigene:79001',
#    'ncbigene:79001',
#    'GO:0007596']],
#  ('pubchem.compound:5282136',
#   'GO:0001696'): [['pubchem.compound:5282136',
#    'pubchem.compound:5282136',
#    'ncbigene:3274',
#    'GO:0001696'], ['pubchem.compound:5282136',
#    'ncbigene:3274',
#    'GO:0001696',
#    'GO:0001696'], ['pubchem.compound:5282136',
#    'ncbigene:3274',
#    'ncbigene:3274',
#    'GO:0001696']],
#  ('pubchem.compound:3446',
#   'GO:0006936'): [['pubchem.compound:3446',
#    'pubchem.compound:3446',
#    'ncbigene:781',
#    'GO:0006936'], ['pubchem.compound:3446',
#    'ncbigene:781',
#    'GO:0006936',
#    'GO:0006936']],
#  ('pubchem.compound:4201',
#   'GO:0008217'): [['pubchem.compound:4201',
#    'ncbigene:3758',
#    'GO:0008217',
#    'GO:0008217'], ['pubchem.compound:4201',
#    'pubchem.compound:4201',
#    'ncbigene:3758',
#    'GO:0008217']],
#  ('pubchem.compound:55191',
#   'GO:0050795'): [['pubchem.compound:55191',
#    'ncbigene:3350',
#    'GO:0050795',
#    'GO:0050795'], ['pubchem.compound:55191',
#    'pubchem.compound:55191',
#    'ncbigene:3350',
#    'GO:0050795']],
#  ('pubchem.compound:135398744',
#   'GO:0042311'): [['pubchem.compound:135398744',
#    'pubchem.compound:135398744',
#    'ncbigene:8654',
#    'GO:0042311'], ['pubchem.compound:135398744',
#    'ncbigene:8654',
#    'GO:0042311',
#    'GO:0042311'], ['pubchem.compound:135398744',
#    'ncbigene:8654',
#    'ncbigene:8654',
#    'GO:0042311']],
#  ('pubchem.compound:25151504',
#   'GO:0019068'): [['pubchem.compound:25151504',
#    'pubchem.compound:25151504',
#    'ncbigene:64816',
#    'GO:0019068'], ['pubchem.compound:25151504',
#    'ncbigene:64816',
#    'GO:0019068',
#    'GO:0019068'], ['pubchem.compound:25151504',
#    'ncbigene:64816',
#    'ncbigene:64816',
#    'GO:0019068']],
#  ('pubchem.compound:4826',
#   'GO:0042311'): [['pubchem.compound:4826',
#    'pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0042311'], ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0042311',
#    'GO:0042311'], ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'ncbigene:3778',
#    'GO:0042311']],
#  ('pubchem.compound:4976',
#   'GO:0023041'): [['pubchem.compound:4976',
#    'pubchem.compound:4976',
#    'ncbigene:6530',
#    'GO:0023041'], ['pubchem.compound:4976',
#    'ncbigene:6530',
#    'GO:0023041',
#    'GO:0023041'], ['pubchem.compound:4976',
#    'ncbigene:6530',
#    'ncbigene:6530',
#    'GO:0023041']],
#  ('pubchem.compound:4826',
#   'GO:0008217'): [['pubchem.compound:4826',
#    'pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0008217'], ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'GO:0008217',
#    'GO:0008217'], ['pubchem.compound:4826',
#    'ncbigene:3778',
#    'ncbigene:3778',
#    'GO:0008217']]}

# %%
matches = dict()
for key in found_keys:
    true_prots = {i for i in real_moas[key] if i.startswith('ncbigene:')}
    matches[key] = []
    for pred in pred_moas[key]:
        pred_prots = {i for i in pred if i.startswith('ncbigene:')}
        matches[key].append(len(true_prots.intersection(pred_prots)) / len(true_prots))

# %%
matches
# Out:
# {('pubchem.compound:54676537', 'GO:0007596'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:4976', 'GO:0023041'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:4826', 'GO:0042311'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:16197727', 'GO:0009650'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:135398744', 'GO:0042311'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:25151504', 'GO:0019068'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:4201', 'GO:0008217'): [1.0, 1.0],
#  ('pubchem.compound:5282136', 'GO:0001696'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:3446', 'GO:0006936'): [1.0, 1.0],
#  ('pubchem.compound:5339', 'GO:0019370'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:54678486', 'GO:0007596'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:5339', 'GO:0006954'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:4170', 'GO:0055078'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:4826', 'GO:0008217'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:55191', 'GO:0050795'): [1.0, 1.0],
#  ('pubchem.compound:16197727', 'GO:0042438'): [1.0, 1.0, 1.0],
#  ('pubchem.compound:149096', 'GO:0006260'): [1.0, 1.0]}

# %%
real_moas[('pubchem.compound:4636', 'GO:0042310')]
# Out:
# ['pubchem.compound:4636', 'ncbigene:148', 'GO:0042310']

# %%
pred_moas[('pubchem.compound:4636', 'GO:0042310')]
# Out:
# [['pubchem.compound:4636', 'ncbigene:148', 'GO:0042310', 'GO:0042310']]

# %%
validation_moas[('pubchem.compound:4636', 'GO:0042310')]['relations']
# Out:
# ['ACTIVATES', 'UP_REGULATES']

# %%
pred_paths[('pubchem.compound:4636', 'GO:0042310')]['relations']
# Out:
# [['CuG', 'GpBP', 'NO_OP']]

# %% [markdown]
# This is impressive. Are these drugs connected to a lot of proteins?

# %%
KG_DIR = '../data/kg'

kg = pd.read_csv(osp.join(KG_DIR, 'final_kg.tsv'), sep='\t')
kg.drop_duplicates(inplace=True)

# %%
for key in found_keys:
    drug = key[0]
    print(len(kg.loc[kg['source'] == drug]))
    print(key)
# Out:
# 1
# ('pubchem.compound:114905', 'GO:0045823')
# 3
# ('pubchem.compound:149096', 'GO:0006260')
# 1
# ('pubchem.compound:2564', 'GO:0034776')
# 1
# ('pubchem.compound:3162', 'GO:0034776')
# 1
# ('pubchem.compound:4826', 'GO:0008217')
# 1
# ('pubchem.compound:54678486', 'GO:0007596')
# 1
# ('pubchem.compound:60835', 'GO:0051610')
# 1
# ('pubchem.compound:3446', 'GO:0006936')
# 1
# ('pubchem.compound:54676537', 'GO:0007596')
# 1
# ('pubchem.compound:54385', 'GO:0034776')
# 1
# ('pubchem.compound:5339', 'GO:0006954')
# 1
# ('pubchem.compound:135398744', 'GO:0042311')
# 1
# ('pubchem.compound:25151504', 'GO:0019068')
# 1
# ('pubchem.compound:5339', 'GO:0019370')
# 10
# ('pubchem.compound:4636', 'GO:0042310')
# 1
# ('pubchem.compound:4976', 'GO:0023041')
# 1
# ('pubchem.compound:4826', 'GO:0042311')
# 1
# ('pubchem.compound:2200', 'GO:0034776')
# 1
# ('pubchem.compound:16197727', 'GO:0009650')
# 1
# ('pubchem.compound:16197727', 'GO:0042438')
# 1
# ('pubchem.compound:3487', 'GO:1904862')
# 1
# ('pubchem.compound:5282136', 'GO:0001696')
# 1
# ('pubchem.compound:2244', 'GO:0007596')
# 1
# ('pubchem.compound:55191', 'GO:0050795')
# 1
# ('pubchem.compound:4170', 'GO:0055078')

# %%
for key in found_keys:
    bp = key[1]
    entries = len(kg.loc[kg['target'] == bp])
    #if entries > 1:
    print(entries)
    print(key)
# Out:
# 1
# ('pubchem.compound:114905', 'GO:0045823')
# 1
# ('pubchem.compound:149096', 'GO:0006260')
# 1
# ('pubchem.compound:2564', 'GO:0034776')
# 1
# ('pubchem.compound:3162', 'GO:0034776')
# 2
# ('pubchem.compound:4826', 'GO:0008217')
# 2
# ('pubchem.compound:54678486', 'GO:0007596')
# 1
# ('pubchem.compound:60835', 'GO:0051610')
# 1
# ('pubchem.compound:3446', 'GO:0006936')
# 2
# ('pubchem.compound:54676537', 'GO:0007596')
# 1
# ('pubchem.compound:54385', 'GO:0034776')
# 6
# ('pubchem.compound:5339', 'GO:0006954')
# 3
# ('pubchem.compound:135398744', 'GO:0042311')
# 1
# ('pubchem.compound:25151504', 'GO:0019068')
# 2
# ('pubchem.compound:5339', 'GO:0019370')
# 1
# ('pubchem.compound:4636', 'GO:0042310')
# 1
# ('pubchem.compound:4976', 'GO:0023041')
# 3
# ('pubchem.compound:4826', 'GO:0042311')
# 1
# ('pubchem.compound:2200', 'GO:0034776')
# 1
# ('pubchem.compound:16197727', 'GO:0009650')
# 1
# ('pubchem.compound:16197727', 'GO:0042438')
# 1
# ('pubchem.compound:3487', 'GO:1904862')
# 1
# ('pubchem.compound:5282136', 'GO:0001696')
# 2
# ('pubchem.compound:2244', 'GO:0007596')
# 1
# ('pubchem.compound:55191', 'GO:0050795')
# 1
# ('pubchem.compound:4170', 'GO:0055078')

# %%
kg.loc[kg['edge_type'] == 'participates']['target'].unique().shape
# Out:
# (88,)

# %% [markdown]
# ## DrugMechDB overlap with dataset
#
# To use DrugMechDB as a validation set, let's see how much it overlaps with our data.
#
# First, we can see which BPs are also within our GO BP set from the ChEMBL dataset.

# %%
KG_DIR = '../data/kg'

# %%
feasible_bps = pd.read_csv(osp.join(KG_DIR, "feasible_go_bps.tsv"), sep="\t", index_col=0)

# %%
feasible_bps.head()
# Out:
#         go_id                                        go_term  num_drugs  \
# 0  GO:0008150                             biological_process        181
# 1  GO:0010951  negative regulation of endopeptidase activity         33
# 2  GO:0006805                   xenobiotic metabolic process        153
# 3  GO:0006629                        lipid metabolic process        169
# 4  GO:0030154                           cell differentiation        143
#
#    num_prots
# 0         93
# 1         33
# 2         92
# 3        104
# 4        285

# %%
feas_gobps = set(feasible_bps['go_id'])

# %%
venn2_unweighted(
    [feas_gobps, bps],
    set_labels=['GO BPs in ChEMBL dataset', 'GO BPs in DrugMechDB']
)

# %% [markdown]
# Okay, yikes. Only two GO BPs are in the set from ChEMBL. Let's see how the overlap with the KGs is.

# %%
openbiolink_df = pd.read_csv(osp.join(KG_DIR, 'openbiolink_filtered.tsv'), sep='\t')
custom_df = pd.read_csv(osp.join(KG_DIR, 'customkg_filtered.tsv'), sep='\t')

# %% [markdown]
# In the `enrichment` notebook, we made a filtered mapping dataframe with GO annotations:

# %%
MAPPING_DIR = '../data/mappings'

# %%
filtered_df = pd.read_csv('../data/mappings/in_kg_go_terms.tsv', sep='\t')

# %%
filtered_df.head()
# Out:
#    #tax_id      GeneID       GO_ID Evidence    Qualifier  \
# 0     9606  ncbigene:2  GO:0001553      IEA  involved_in
# 1     9606  ncbigene:2  GO:0001869      IDA  involved_in
# 2     9606  ncbigene:2  GO:0002020      IBA      enables
# 3     9606  ncbigene:2  GO:0002020      IPI      enables
# 4     9606  ncbigene:2  GO:0002438      IEA  involved_in
#
#                                              GO_term            PubMed  \
# 0                                      luteinization                 -
# 1  negative regulation of complement activation, ...          12538697
# 2                                   protease binding          21873635
# 3                                   protease binding  7679575|18485748
# 4  acute inflammatory response to antigenic stimulus                 -
#
#    Category
# 0   Process
# 1   Process
# 2  Function
# 3  Function
# 4   Process

# %%
bps_in_kg = set(filtered_df['GO_ID'])

# %%
venn2_unweighted(
    [bps_in_kg, bps],
    set_labels=['GO BPs in KGs', 'GO BPs in DrugMechDB']
)

# %%
from matplotlib_venn import venn3_unweighted

# %%
venn3_unweighted(
    [bps_in_kg, bps, feas_gobps],
    set_labels=['GO BPs in KGs', 'GO BPs in DrugMechDB', 'GO BPs in ChEMBL']
)

# %% [markdown]
# Cool, at least most of them exist in the KG! That is important because we know they are at least connected to a protein and can be mapped.
#
# What about the drugs between DrugMechDB and the KG? First, we will have to map the drugs from DrugBank to PubChem.

# %%
# Get all the KG drugs:
obl_drugs = {d for d in openbiolink_df['source'] if 'pubchem.compound' in d}
custom_drugs = {d for d in custom_df['source'] if 'pubchem.compound' in d}

# %%
custom_drugs.update(obl_drugs)

# %% [markdown]
# I got a mapping file from [DrugBank](https://go.drugbank.com), which requires a private login/ license.

# %%
drugbank_mapping = pd.read_csv(osp.join(MAPPING_DIR, "drugbank_all_drug_links.csv.zip"))

# %%
drugbank_mapping.head()
# Out:
#   DrugBank ID                 Name   CAS Number    Drug Type KEGG Compound ID  \
# 0     DB00001            Lepirudin  138068-37-8  BiotechDrug              NaN
# 1     DB00002            Cetuximab  205923-56-4  BiotechDrug              NaN
# 2     DB00003         Dornase alfa  143831-71-4  BiotechDrug              NaN
# 3     DB00004  Denileukin diftitox  173146-27-5  BiotechDrug              NaN
# 4     DB00005           Etanercept  185243-69-0  BiotechDrug           C07897
#
#   KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  ChEBI ID  \
# 0       D06880                  NaN            46507011.0       NaN
# 1       D03455                  NaN            46507042.0       NaN
# 2          NaN                  NaN            46507792.0       NaN
# 3          NaN                  NaN            46506950.0       NaN
# 4       D00742                  NaN            46506732.0       NaN
#
#    PharmGKB ID  ... GenBank ID DPD ID  \
# 0     PA450195  ...        NaN  11916
# 1      PA10040  ...     J00228  13175
# 2      PA10318  ...     M55983    650
# 3  PA164750594  ...     V01536    NaN
# 4     PA449515  ...     M32315  12032
#
#                                          RxList Link Pdrhealth Link  \
# 0    http://www.rxlist.com/cgi/generic/lepirudin.htm            NaN
# 1     http://www.rxlist.com/cgi/generic3/erbitux.htm            NaN
# 2    http://www.rxlist.com/cgi/generic/pulmozyme.htm            NaN
# 3  http://www.rxlist.com/cgi/generic2/denileukin.htm            NaN
# 4   http://www.rxlist.com/cgi/generic/etanercept.htm            NaN
#
#           Wikipedia ID                                     Drugs.com Link  \
# 0            Lepirudin            http://www.drugs.com/cdi/lepirudin.html
# 1            Cetuximab            http://www.drugs.com/cdi/cetuximab.html
# 2         Dornase_alfa         http://www.drugs.com/cdi/dornase-alfa.html
# 3  Denileukin_diftitox  http://www.drugs.com/cdi/denileukin-diftitox.html
# 4           Etanercept           http://www.drugs.com/cdi/etanercept.html
#
#   NDC ID ChemSpider ID BindingDB ID     TTD ID
# 0    NaN           NaN          NaN  DAP000541
# 1    NaN           NaN          NaN  DNC000788
# 2    NaN           NaN          NaN  DAP000981
# 3    NaN           NaN          NaN  DAP001098
# 4    NaN           NaN          NaN  DNC000605
#
# [5 rows x 23 columns]

# %% [markdown]
# Looks like we need the PubChem IDs without their prefixes:

# %%
cids = [cid.split(':')[1] for cid in custom_drugs]

# %% [markdown]
# The PubChem IDs are floats in the table. This is probably because there are NaNs.

# %%
drugbank_mapping.columns
# Out:
# Index(['DrugBank ID', 'Name', 'CAS Number', 'Drug Type', 'KEGG Compound ID',
#        'KEGG Drug ID', 'PubChem Compound ID', 'PubChem Substance ID',
#        'ChEBI ID', 'PharmGKB ID', 'HET ID', 'UniProt ID', 'UniProt Title',
#        'GenBank ID', 'DPD ID', 'RxList Link', 'Pdrhealth Link', 'Wikipedia ID',
#        'Drugs.com Link', 'NDC ID', 'ChemSpider ID', 'BindingDB ID', 'TTD ID'],
#       dtype='object')

# %%
db2pc = {}
for dbid, pcid in zip(drugbank_mapping['DrugBank ID'], drugbank_mapping['PubChem Compound ID']):
    if not math.isnan(pcid):
        db2pc[dbid] = int(pcid)
    #else:
    #    db2pc[dbid] = pcid

# %%
# Get all drugs from DrugMechDB
dmdb_drugs = set(indications['db_id'])

# %%
venn2_unweighted(
    [set(db2pc.keys()), dmdb_drugs],
    set_labels=['DrugBank IDs with mappings', 'Drugs in DrugMechDB']
)

# %% [markdown]
# 15 of the drugs in DrugMechDB do not have mappings in this file.
#
# For some, this is because these drugs are small proteins or don't have a discrete structure.
#
# For others, the reference is just missing, so I looked them up manually:

# %%
db2pc['DB11254'] = '3610'
db2pc['DB00994'] = '8378'
db2pc['DB06762'] = '4826'
db2pc['DB11100'] = '204'
db2pc['DB11152'] = '119236'
db2pc['DB13676'] = '4257'

# %%
venn2_unweighted(
    [set(db2pc.keys()), dmdb_drugs],
    set_labels=['DrugBank IDs with mappings', 'Drugs in DrugMechDB']
)

# %%
dmdb_drug_pc_ids = {str(db2pc[d]) for d in set(db2pc.keys()).intersection(dmdb_drugs)}

# %%
len(dmdb_drug_pc_ids)
# Out:
# 94

# %%
venn2_unweighted(
    [set(cids), dmdb_drug_pc_ids],
    set_labels=['Drugs in KG', 'Drugs in DrugMechDB']
)

# %% [markdown]
# Only 22 of those 94 are in the KG. Is it worth incorporating the 72 into the KG? Perhaps we can see whether their protein targets are already in the KG, and whether we need to incorporate them.
#
# ### Protein Overlap
#
# First, let's get all the proteins from the paths and see how many of them are in the KG.

# %%
prots_in_kg = set(filtered_df['GeneID'])

# %%
dmdb_proteins = set()
for path in bp_paths:
    for node in path['nodes']:
        if node['label'] == 'Protein':
            dmdb_proteins.add(node['id'])

# %%
len(dmdb_proteins)
# Out:
# 56

# %%
dmdb_proteins
# Out:
# {'MESH:D012338',
#  'MESH:Q14145',
#  'UniProt:O05131',
#  'UniProt:O43497',
#  'UniProt:O76074',
#  'UniProt:P01148',
#  'UniProt:P04083',
#  'UniProt:P04150',
#  'UniProt:P04585',
#  'UniProt:P06401',
#  'UniProt:P08546',
#  'UniProt:P08588',
#  'UniProt:P08908',
#  'UniProt:P09917',
#  'UniProt:P0A0H0',
#  'UniProt:P0A298',
#  'UniProt:P0A7J3',
#  'UniProt:P0A7S3',
#  'UniProt:P0C1U9',
#  'UniProt:P10275',
#  'UniProt:P10721',
#  'UniProt:P11388',
#  'UniProt:P11511',
#  'UniProt:P14416',
#  'UniProt:P14867',
#  'UniProt:P16234',
#  'UniProt:P19235',
#  'UniProt:P20831',
#  'UniProt:P22301',
#  'UniProt:P23219',
#  'UniProt:P23945',
#  'UniProt:P23975',
#  'UniProt:P25021',
#  'UniProt:P31645',
#  'UniProt:P35348',
#  'UniProt:P35354',
#  'UniProt:P35367',
#  'UniProt:P35372',
#  'UniProt:P43702',
#  'UniProt:P44350',
#  'UniProt:P47712',
#  'UniProt:P48048',
#  'UniProt:P48357',
#  'UniProt:P54289',
#  'UniProt:P55017',
#  'UniProt:P71707',
#  'UniProt:P72525',
#  'UniProt:P9WGY7',
#  'UniProt:Q01726',
#  'UniProt:Q12791',
#  'UniProt:Q16236',
#  'UniProt:Q81VT3',
#  'UniProt:Q8DR59',
#  'UniProt:Q9BQB6',
#  'UniProt:Q9HB55',
#  'UniProt:Q9NZQ7'}

# %% [markdown]
# If we look into those proteins, most have [UniProt](https://www.uniprot.org) IDs, but some are under [MeSH](https://www.nlm.nih.gov/mesh/meshhome.html) terms.
#
# MESH:Q14145, can not even be found in the MeSH browser.
#
# I will just look at the UniProt proteins then. I will need to map them to ncbi gene IDs first:

# %%
# get rid of MeSh terms:
dmdb_proteins = {p for p in dmdb_proteins if 'UniProt' in p}

# %%
def uniprot2ncbi(uniprot_ids):
    """Outputs a dictionary mapping from uniprot IDs to ncbi gene IDs.
    :param uniprot_ids: a list of uniprot IDs with UniProt: prefix
    :returns: dictionary with uniprot as keys as ncbi gene as values
    """
    up2ncbi = {up_id: None for up_id in uniprot_ids}
    for up_id in tqdm(uniprot_ids):
        up = up_id.split(':')[1]
        r = requests.get(f'https://rest.uniprot.org/uniprotkb/search?query={up}')
        xrefs = r.json()['results'][0]['uniProtKBCrossReferences']
        for xref in xrefs:
            if xref['database'] == 'GeneID':
                up2ncbi[up_id] = 'ncbigene:' + xref['id']
                break
    return up2ncbi

# %%
dmdb_prot_mappings = uniprot2ncbi(dmdb_proteins)
# Out:
# 100%|█████████████████████████████████████████████████| 54/54 [00:18<00:00,  2.89it/s]

# %% [markdown]
# How many did not map?

# %%
len([i for i in dmdb_prot_mappings.values() if i == None])
# Out:
# 8

# %% [markdown]
# How many in the KG?

# %%
venn2_unweighted(
    [prots_in_kg, set(dmdb_prot_mappings.values())],
    set_labels=['Proteins in KG', 'Proteins in DrugMechDB']
)

# %% [markdown]
# Which one is not in the KG?

# %%
set(dmdb_prot_mappings.values()) - prots_in_kg
# Out:
# {None,
#  'ncbigene:155348',
#  'ncbigene:3920380',
#  'ncbigene:45020152',
#  'ncbigene:67415314',
#  'ncbigene:67460217',
#  'ncbigene:67463992',
#  'ncbigene:887065',
#  'ncbigene:888177'}

# %% [markdown]
# It's [Gag-Pol / Human immunodeficiency virus 1 ](https://www.ncbi.nlm.nih.gov/gene/?term=155348). Makes sense as it is actually a viral protein. How many BP paths is it involved in?

# %%
# TO BE FINISHED

# %% [markdown]
# The DrugBank recorded targets:

# %%
db_uniprot_mapping = pd.read_csv(osp.join(MAPPING_DIR, "drugbank_all_target_uniprot_links.csv.zip"))

# %%
db_uniprot_mapping.head()
# Out:
#   DrugBank ID       Name         Type UniProt ID  \
# 0     DB00001  Lepirudin  BiotechDrug     P00734
# 1     DB00002  Cetuximab  BiotechDrug     P00533
# 2     DB00002  Cetuximab  BiotechDrug     O75015
# 3     DB00002  Cetuximab  BiotechDrug     P02745
# 4     DB00002  Cetuximab  BiotechDrug     P02746
#
#                                         UniProt Name
# 0                                        Prothrombin
# 1                   Epidermal growth factor receptor
# 2  Low affinity immunoglobulin gamma Fc region re...
# 3              Complement C1q subcomponent subunit A
# 4              Complement C1q subcomponent subunit B

# %% [markdown]
# ## Metapaths
#
# Finally, let's explore the metapaths a bit.
#
# There are two sheets for metapaths. One is the original metapaths:

# %%
metapaths = pd.read_excel(dm_db, 'metapaths')

# %%
metapaths.head()
# Out:
#      n1        e1       n2               e2                  n3      e3  \
# 0  Drug  INHIBITS  Protein           CAUSES             Disease     NaN
# 1  Drug  INHIBITS  Protein     UP_REGULATES  Biological Process  CAUSES
# 2  Drug  INHIBITS  Protein     UP_REGULATES  Biological Process  CAUSES
# 3  Drug  INHIBITS  Pathway  ASSOCIATED_WITH             Disease     NaN
# 4  Drug  INHIBITS  Protein         PRODUCES      Compound Class  CAUSES
#
#         n4   e4   n5   e5   n6   e6   n7   e7   n8
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ... and another is Biolink metapaths:
#
# `"Version 1.1.0 includes a new tab 'metapaths_biolink' where the majority of node and edge types have been mapped to entities and relationship slots in the biolink model."`

# %%
metapaths_biolink = pd.read_excel(dm_db, 'metapaths_biolink')

# %%
metapaths_biolink.head()
# Out:
#      n1                     e1       n2                      e2  \
# 0  Drug  decreases activity of  Protein                  causes
# 1  Drug  decreases activity of  Protein    positively regulates
# 2  Drug  decreases activity of  Protein    positively regulates
# 3  Drug   negatively regulates  Pathway        affects risk for
# 4  Drug  decreases activity of  Protein  increases abundance of
#
#                   n3      e3       n4   e4   n5   e5   n6   e6   n7   e7   n8
# 0            Disease     NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  BiologicalProcess  causes  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  BiologicalProcess  causes  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3            Disease     NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                NaN  causes  Disease  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# I think we'll use the biolink-adjusted ones. How long are these metapaths, typically?

# %%
Counter([(row.count() - 1) / 2 for i, row in metapaths_biolink.iterrows()])
# Out:
# Counter({4.0: 55,
#          3.0: 33,
#          2.0: 13,
#          5.0: 7,
#          2.5: 5,
#          3.5: 4,
#          1.0: 3,
#          4.5: 1,
#          6.5: 1,
#          6.0: 1})

# %% [markdown]
# This is pretty weird, since some of the metapaths have NaN in them. Otherwise, we wouldn't be getting anything other than integers for the path lengths.
#
# What does NaN mean? Can it be any entity?
#
# Maybe this is a problem with converting everything to Biolink- let's try the original DF:

# %%
len(metapaths)
# Out:
# 123

# %%
Counter([(row.count() - 1) / 2 for i, row in metapaths.iterrows()])
# Out:
# Counter({4.0: 59, 3.0: 38, 2.0: 13, 5.0: 8, 1.0: 3, 7.0: 1, 6.0: 1})

# %% [markdown]
# For now, we aren't really using these metapaths, so I will conclude that exploration there.
